# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/Users/jlhudd/miniconda3/envs/nextstrain/lib/python3.6/site-packages', '/Users/jlhudd/projects/docker/flu-forecasting-submission/notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x03csnakemake.script\nSnakemake\nq\x00)\x81q\x01}q\x02(X\x05\x00\x00\x00inputq\x03csnakemake.io\nInputFiles\nq\x04)\x81q\x05(Xf\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding/tip_attributes_with_weighted_distances.tsvq\x06Xp\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding_test_tree/tip_attributes_with_weighted_distances.tsvq\x07XZ\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding/forecasts_cTiter_x-ne_star.tsvq\x08XU\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding/forecasts_ne_star-lbi.tsvq\tXO\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding/forecasts_naive.tsvq\nXd\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding_test_tree/forecasts_cTiter_x-ne_star.tsvq\x0bX_\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding_test_tree/forecasts_ne_star-lbi.tsvq\x0cXY\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding_test_tree/forecasts_naive.tsvq\rX\x19\x00\x00\x00config/vaccines_h3n2.jsonq\x0ee}q\x0f(X\x06\x00\x00\x00_namesq\x10}q\x11(X\x19\x00\x00\x00validation_tip_attributesq\x12K\x00N\x86q\x13X\x13\x00\x00\x00test_tip_attributesq\x14K\x01N\x86q\x15X*\x00\x00\x00cTiter_x_ne_star_validation_forecasts_pathq\x16K\x02N\x86q\x17X%\x00\x00\x00ne_star_lbi_validation_forecasts_pathq\x18K\x03N\x86q\x19X\x1f\x00\x00\x00naive_validation_forecasts_pathq\x1aK\x04N\x86q\x1bX$\x00\x00\x00cTiter_x_ne_star_test_forecasts_pathq\x1cK\x05N\x86q\x1dX\x1f\x00\x00\x00ne_star_lbi_test_forecasts_pathq\x1eK\x06N\x86q\x1fX\x19\x00\x00\x00naive_test_forecasts_pathq K\x07N\x86q!X\x12\x00\x00\x00vaccines_json_pathq"K\x08N\x86q#uX\x12\x00\x00\x00_allowed_overridesq$]q%(X\x05\x00\x00\x00indexq&X\x04\x00\x00\x00sortq\'eh&cfunctools\npartial\nq(cbuiltins\ngetattr\nq)csnakemake.io\nNamedlist\nq*X\x0f\x00\x00\x00_used_attributeq+\x86q,Rq-\x85q.Rq/(h-)}q0X\x05\x00\x00\x00_nameq1h&sNtq2bh\'h(h-\x85q3Rq4(h-)}q5h1h\'sNtq6bh\x12h\x06h\x14h\x07h\x16h\x08h\x18h\th\x1ah\nh\x1ch\x0bh\x1eh\x0ch h\rh"h\x0eubX\x06\x00\x00\x00outputq7csnakemake.io\nOutputFiles\nq8)\x81q9(X)\x00\x00\x00manuscript/figures/vaccine-comparison.pdfq:X;\x00\x00\x00manuscript/figures/vaccine-comparison-relative-distance.pdfq;e}q<(h\x10}q=(X\x06\x00\x00\x00figureq>K\x00N\x86q?X\x0f\x00\x00\x00relative_figureq@K\x01N\x86qAuh$]qB(h&h\'eh&h(h-\x85qCRqD(h-)}qEh1h&sNtqFbh\'h(h-\x85qGRqH(h-)}qIh1h\'sNtqJbh>h:h@h;ubX\x06\x00\x00\x00paramsqKcsnakemake.io\nParams\nqL)\x81qM}qN(h\x10}qOh$]qP(h&h\'eh&h(h-\x85qQRqR(h-)}qSh1h&sNtqTbh\'h(h-\x85qURqV(h-)}qWh1h\'sNtqXbubX\t\x00\x00\x00wildcardsqYcsnakemake.io\nWildcards\nqZ)\x81q[}q\\(h\x10}q]h$]q^(h&h\'eh&h(h-\x85q_Rq`(h-)}qah1h&sNtqbbh\'h(h-\x85qcRqd(h-)}qeh1h\'sNtqfbubX\x07\x00\x00\x00threadsqgK\x01X\t\x00\x00\x00resourcesqhcsnakemake.io\nResources\nqi)\x81qj(K\x01K\x01e}qk(h\x10}ql(X\x06\x00\x00\x00_coresqmK\x00N\x86qnX\x06\x00\x00\x00_nodesqoK\x01N\x86qpuh$]qq(h&h\'eh&h(h-\x85qrRqs(h-)}qth1h&sNtqubh\'h(h-\x85qvRqw(h-)}qxh1h\'sNtqybhmK\x01hoK\x01ubX\x03\x00\x00\x00logqzcsnakemake.io\nLog\nq{)\x81q|X.\x00\x00\x00logs/notebooks/vaccine-strain-comparison.ipynbq}a}q~(h\x10}q\x7fX\x08\x00\x00\x00notebookq\x80K\x00N\x86q\x81sh$]q\x82(h&h\'eh&h(h-\x85q\x83Rq\x84(h-)}q\x85h1h&sNtq\x86bh\'h(h-\x85q\x87Rq\x88(h-)}q\x89h1h\'sNtq\x8abh\x80h}ubX\x06\x00\x00\x00configq\x8b}q\x8c(X\r\x00\x00\x00active_buildsq\x8dX\x9b\x00\x00\x00simulated_sample_3 simulated_sample_3_test_tree natural_sample_1_with_90_vpm_sliding natural_sample_1_with_90_vpm_sliding_test_tree natural_sample_20191001q\x8eX\x08\x00\x00\x00datasetsq\x8f}q\x90(X\x12\x00\x00\x00simulated_sample_1q\x91}q\x92(X\x0b\x00\x00\x00descriptionq\x93X^\x00\x00\x00Require a minimum fitness for randomly select amino acids in non-stationary positive selectionq\x94X\x04\x00\x00\x00seedq\x95K\x01X\x07\x00\x00\x00lineageq\x96X\t\x00\x00\x00simulatedq\x97X\x07\x00\x00\x00segmentq\x98X\x02\x00\x00\x00haq\x99X\x11\x00\x00\x00viruses_per_monthq\x9aK\nuX\x12\x00\x00\x00simulated_sample_3q\x9b}q\x9c(h\x93XZ\x00\x00\x00Highest density sampling of simulated populations with same settings as simulated_sample_1q\x9dh\x95K\x03h\x96X\t\x00\x00\x00simulatedq\x9eh\x98X\x02\x00\x00\x00haq\x9fh\x9aKZuX\x1c\x00\x00\x00natural_sample_1_with_90_vpmq\xa0}q\xa1(h\x96X\x04\x00\x00\x00h3n2q\xa2h\x98X\x02\x00\x00\x00haq\xa3X\x0c\x00\x00\x00fauna_fieldsq\xa4Xr\x00\x00\x00strain virus accession collection_date region country division location passage_category submitting_lab age genderq\xa5X\x0c\x00\x00\x00fasta_fieldsq\xa6X^\x00\x00\x00strain virus accession date region country division location passage submitting_lab age genderq\xa7X\x0f\x00\x00\x00titer_databasesq\xa8X(\x00\x00\x00tdb cdc_tdb crick_tdb vidrl_tdb niid_tdbq\xa9X\x0b\x00\x00\x00titer_assayq\xaaX\x02\x00\x00\x00hiq\xabX\r\x00\x00\x00titer_passageq\xacX\x04\x00\x00\x00cellq\xadh\x9aKZX\x13\x00\x00\x00min_sequence_lengthq\xaeM\x84\x03X\x08\x00\x00\x00outliersq\xafX\x18\x00\x00\x00config/outliers_h3n2.txtq\xb0X\x10\x00\x00\x00required_strainsq\xb1X\x1a\x00\x00\x00config/references_h3n2.txtq\xb2X\x0e\x00\x00\x00frozen_strainsq\xb3X<\x00\x00\x00data/natural/natural_sample_1_with_90_vpm/frozen_strains.txtq\xb4X\n\x00\x00\x00start_dateq\xb5X\n\x00\x00\x001990-10-01q\xb6X\x08\x00\x00\x00end_dateq\xb7X\n\x00\x00\x002015-10-01q\xb8uX&\x00\x00\x00natural_sample_1_with_90_vpm_test_treeq\xb9}q\xba(h\x96X\x04\x00\x00\x00h3n2q\xbbh\x98X\x02\x00\x00\x00haq\xbch\xa4Xr\x00\x00\x00strain virus accession collection_date region country division location passage_category submitting_lab age genderq\xbdh\xa6X^\x00\x00\x00strain virus accession date region country division location passage submitting_lab age genderq\xbeh\xa8X(\x00\x00\x00tdb cdc_tdb crick_tdb vidrl_tdb niid_tdbq\xbfh\xaaX\x02\x00\x00\x00hiq\xc0h\xacX\x04\x00\x00\x00cellq\xc1h\x9aKZh\xaeM\x84\x03h\xafX\x18\x00\x00\x00config/outliers_h3n2.txtq\xc2h\xb1X\x1a\x00\x00\x00config/references_h3n2.txtq\xc3h\xb3XF\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/frozen_strains.txtq\xc4h\xb5X\n\x00\x00\x001990-10-01q\xc5h\xb7X\n\x00\x00\x002019-10-01q\xc6uuX\x06\x00\x00\x00buildsq\xc7}q\xc8(X\t\x00\x00\x00simulatedq\xc9}q\xca(h\x91}q\xcb(h\x93X-\x00\x00\x00Analysis of simulated A/H3N2-like populationsq\xccX\t\x00\x00\x00sequencesq\xcdX:\x00\x00\x00data/simulated/simulated_sample_1/filtered_sequences.fastaq\xceX\x08\x00\x00\x00metadataq\xcfX7\x00\x00\x00data/simulated/simulated_sample_1/filtered_metadata.tsvq\xd0X\x07\x00\x00\x00strainsq\xd1X-\x00\x00\x00data/simulated/simulated_sample_1/strains.txtq\xd2h\xb5X\n\x00\x00\x002010-10-01q\xd3h\xb7X\n\x00\x00\x002040-10-01q\xd4X\x0e\x00\x00\x00pivot_intervalq\xd5K\x06X\x13\x00\x00\x00min_years_per_buildq\xd6K\x06X\x19\x00\x00\x00years_back_to_build_treesq\xd7K\x06X\t\x00\x00\x00referenceq\xd8X\x1b\x00\x00\x00config/reference_h3n2_ha.gbq\xd9X\n\x00\x00\x00predictorsq\xda]q\xdb(X\x05\x00\x00\x00naiveq\xdcX\x12\x00\x00\x00normalized_fitnessq\xddX\x04\x00\x00\x00ep_xq\xdeX\x07\x00\x00\x00ne_starq\xdfX\x03\x00\x00\x00lbiq\xe0X\x0f\x00\x00\x00delta_frequencyq\xe1X\x0b\x00\x00\x00lbi-ne_starq\xe2eX\x0e\x00\x00\x00best_predictorq\xe3X_\x00\x00\x00results/builds/simulated/simulated_sample_1/minimal_models_by_distances/normalized_fitness.jsonq\xe4uX\x1c\x00\x00\x00simulated_sample_1_full_treeq\xe5}q\xe6(X\x0e\x00\x00\x00dataset_sampleq\xe7X\x12\x00\x00\x00simulated_sample_1q\xe8h\x93XB\x00\x00\x00Full tree for analysis of sparse simulated A/H3N2-like populationsq\xe9h\xcdX:\x00\x00\x00data/simulated/simulated_sample_1/filtered_sequences.fastaq\xeah\xcfX7\x00\x00\x00data/simulated/simulated_sample_1/filtered_metadata.tsvq\xebh\xd1X-\x00\x00\x00data/simulated/simulated_sample_1/strains.txtq\xech\xb5X\n\x00\x00\x002010-10-01q\xedh\xb7X\n\x00\x00\x002040-10-01q\xeeh\xd5K\x06h\xd6K\x1eh\xd7K\x1eh\xd8X\x1b\x00\x00\x00config/reference_h3n2_ha.gbq\xefh\xe3X_\x00\x00\x00results/builds/simulated/simulated_sample_1/minimal_models_by_distances/normalized_fitness.jsonq\xf0uX\x1c\x00\x00\x00simulated_sample_1_test_treeq\xf1}q\xf2(h\xe7X\x12\x00\x00\x00simulated_sample_1q\xf3h\x93XB\x00\x00\x00Test data for analysis of sparse simulated A/H3N2-like populationsq\xf4h\xcdX:\x00\x00\x00data/simulated/simulated_sample_1/filtered_sequences.fastaq\xf5h\xcfX7\x00\x00\x00data/simulated/simulated_sample_1/filtered_metadata.tsvq\xf6h\xd1X-\x00\x00\x00data/simulated/simulated_sample_1/strains.txtq\xf7h\xb5X\n\x00\x00\x002034-10-01q\xf8h\xb7X\n\x00\x00\x002050-10-01q\xf9h\xd5K\x06h\xd6K\x06h\xd7K\x06h\xd8X\x1b\x00\x00\x00config/reference_h3n2_ha.gbq\xfah\xe3X_\x00\x00\x00results/builds/simulated/simulated_sample_1/minimal_models_by_distances/normalized_fitness.jsonq\xfbuh\x9b}q\xfc(h\x93X<\x00\x00\x00Analysis of simulated A/H3N2-like populations (current best)q\xfdX\x0f\x00\x00\x00full_tree_buildq\xfeX\x1c\x00\x00\x00simulated_sample_3_full_treeq\xffh\xcdX:\x00\x00\x00data/simulated/simulated_sample_3/filtered_sequences.fastar\x00\x01\x00\x00h\xcfX7\x00\x00\x00data/simulated/simulated_sample_3/filtered_metadata.tsvr\x01\x01\x00\x00h\xd1X-\x00\x00\x00data/simulated/simulated_sample_3/strains.txtr\x02\x01\x00\x00h\xb5X\n\x00\x00\x002010-10-01r\x03\x01\x00\x00h\xb7X\n\x00\x00\x002040-10-01r\x04\x01\x00\x00h\xd5K\x06h\xd6K\x06h\xd7K\x06h\xd8X\x1b\x00\x00\x00config/reference_h3n2_ha.gbr\x05\x01\x00\x00h\xda]r\x06\x01\x00\x00(X\x05\x00\x00\x00naiver\x07\x01\x00\x00X\x12\x00\x00\x00normalized_fitnessr\x08\x01\x00\x00X\x07\x00\x00\x00ep_starr\t\x01\x00\x00X\x04\x00\x00\x00ep_xr\n\x01\x00\x00X\x07\x00\x00\x00ne_starr\x0b\x01\x00\x00X\x03\x00\x00\x00lbir\x0c\x01\x00\x00X\x0f\x00\x00\x00delta_frequencyr\r\x01\x00\x00X\x0f\x00\x00\x00ep_star-ne_starr\x0e\x01\x00\x00X\x0c\x00\x00\x00ep_x-ne_starr\x0f\x01\x00\x00X\x0b\x00\x00\x00lbi-ne_starr\x10\x01\x00\x00eh\xe3X_\x00\x00\x00results/builds/simulated/simulated_sample_3/minimal_models_by_distances/normalized_fitness.jsonr\x11\x01\x00\x00X\x15\x00\x00\x00validation_predictorsr\x12\x01\x00\x00]r\x13\x01\x00\x00(X\x05\x00\x00\x00naiver\x14\x01\x00\x00X\x0b\x00\x00\x00lbi-ne_starr\x15\x01\x00\x00X\x12\x00\x00\x00normalized_fitnessr\x16\x01\x00\x00euX\x1c\x00\x00\x00simulated_sample_3_full_treer\x17\x01\x00\x00}r\x18\x01\x00\x00(h\xe7X\x12\x00\x00\x00simulated_sample_3r\x19\x01\x00\x00h\x93XA\x00\x00\x00Full tree for analysis of dense simulated A/H3N2-like populationsr\x1a\x01\x00\x00h\xcdX:\x00\x00\x00data/simulated/simulated_sample_3/filtered_sequences.fastar\x1b\x01\x00\x00h\xcfX7\x00\x00\x00data/simulated/simulated_sample_3/filtered_metadata.tsvr\x1c\x01\x00\x00h\xd1X-\x00\x00\x00data/simulated/simulated_sample_3/strains.txtr\x1d\x01\x00\x00h\xb5X\n\x00\x00\x002030-10-01r\x1e\x01\x00\x00h\xb7X\n\x00\x00\x002040-10-01r\x1f\x01\x00\x00h\xd5K\x06h\xd6K\nh\xd7K\nh\xd8X\x1b\x00\x00\x00config/reference_h3n2_ha.gbr \x01\x00\x00h\xe3X_\x00\x00\x00results/builds/simulated/simulated_sample_3/minimal_models_by_distances/normalized_fitness.jsonr!\x01\x00\x00uX\x1c\x00\x00\x00simulated_sample_3_test_treer"\x01\x00\x00}r#\x01\x00\x00(h\xe7X\x12\x00\x00\x00simulated_sample_3r$\x01\x00\x00X\x10\x00\x00\x00validation_buildr%\x01\x00\x00X\x12\x00\x00\x00simulated_sample_3r&\x01\x00\x00h\xfeX!\x00\x00\x00simulated_sample_3_full_test_treer\'\x01\x00\x00h\x93XA\x00\x00\x00Test data for analysis of dense simulated A/H3N2-like populationsr(\x01\x00\x00h\xcdX:\x00\x00\x00data/simulated/simulated_sample_3/filtered_sequences.fastar)\x01\x00\x00h\xcfX7\x00\x00\x00data/simulated/simulated_sample_3/filtered_metadata.tsvr*\x01\x00\x00h\xd1X-\x00\x00\x00data/simulated/simulated_sample_3/strains.txtr+\x01\x00\x00h\xb5X\n\x00\x00\x002034-04-01r,\x01\x00\x00h\xb7X\n\x00\x00\x002049-10-01r-\x01\x00\x00h\xd5K\x06h\xd6K\x06h\xd7K\x06h\xd8X\x1b\x00\x00\x00config/reference_h3n2_ha.gbr.\x01\x00\x00h\xda]r/\x01\x00\x00(X\x05\x00\x00\x00naiver0\x01\x00\x00X\x12\x00\x00\x00normalized_fitnessr1\x01\x00\x00X\x07\x00\x00\x00ep_starr2\x01\x00\x00X\x04\x00\x00\x00ep_xr3\x01\x00\x00X\x07\x00\x00\x00ne_starr4\x01\x00\x00X\x03\x00\x00\x00lbir5\x01\x00\x00X\x0f\x00\x00\x00delta_frequencyr6\x01\x00\x00X\x0f\x00\x00\x00ep_star-ne_starr7\x01\x00\x00X\x0c\x00\x00\x00ep_x-ne_starr8\x01\x00\x00X\x0b\x00\x00\x00lbi-ne_starr9\x01\x00\x00eh\xe3X_\x00\x00\x00results/builds/simulated/simulated_sample_3/minimal_models_by_distances/normalized_fitness.jsonr:\x01\x00\x00j\x12\x01\x00\x00]r;\x01\x00\x00(X\x05\x00\x00\x00naiver<\x01\x00\x00X\x0b\x00\x00\x00lbi-ne_starr=\x01\x00\x00X\x12\x00\x00\x00normalized_fitnessr>\x01\x00\x00euX!\x00\x00\x00simulated_sample_3_full_test_treer?\x01\x00\x00}r@\x01\x00\x00(h\xe7X\x12\x00\x00\x00simulated_sample_3rA\x01\x00\x00h\x93XO\x00\x00\x00Full tree for test data for analysis of dense simulated A/H3N2-like populationsrB\x01\x00\x00h\xcdX:\x00\x00\x00data/simulated/simulated_sample_3/filtered_sequences.fastarC\x01\x00\x00h\xcfX7\x00\x00\x00data/simulated/simulated_sample_3/filtered_metadata.tsvrD\x01\x00\x00h\xd1X-\x00\x00\x00data/simulated/simulated_sample_3/strains.txtrE\x01\x00\x00h\xb5X\n\x00\x00\x002039-10-01rF\x01\x00\x00h\xb7X\n\x00\x00\x002049-10-01rG\x01\x00\x00h\xd5K\x06h\xd6K\nh\xd7K\nh\xd8X\x1b\x00\x00\x00config/reference_h3n2_ha.gbrH\x01\x00\x00h\xe3X_\x00\x00\x00results/builds/simulated/simulated_sample_3/minimal_models_by_distances/normalized_fitness.jsonrI\x01\x00\x00uuX\x07\x00\x00\x00naturalrJ\x01\x00\x00}rK\x01\x00\x00(X$\x00\x00\x00natural_sample_1_with_90_vpm_slidingrL\x01\x00\x00}rM\x01\x00\x00(h\x93X\x82\x00\x00\x00Very dense sampling of viruses over 25 years of H3N2 evolution after filtering outliers that don\'t match clock rate (current best)rN\x01\x00\x00h\xe7X\x1c\x00\x00\x00natural_sample_1_with_90_vpmrO\x01\x00\x00h\xfeX.\x00\x00\x00natural_sample_1_with_90_vpm_sliding_full_treerP\x01\x00\x00h\xcdXB\x00\x00\x00data/natural/natural_sample_1_with_90_vpm/filtered_sequences.fastarQ\x01\x00\x00h\xcfX>\x00\x00\x00data/natural/natural_sample_1_with_90_vpm/strains_metadata.tsvrR\x01\x00\x00X\x06\x00\x00\x00titersrS\x01\x00\x00X4\x00\x00\x00data/natural/natural_sample_1_with_90_vpm/titers.tsvrT\x01\x00\x00h\xb5X\n\x00\x00\x001990-10-01rU\x01\x00\x00h\xb7X\n\x00\x00\x002015-10-01rV\x01\x00\x00h\xd5K\x06h\xd6K\x06h\xd7K\x06h\xd8X\x1b\x00\x00\x00config/reference_h3n2_ha.gbrW\x01\x00\x00h\xda]rX\x01\x00\x00(X\x05\x00\x00\x00naiverY\x01\x00\x00X\x07\x00\x00\x00ep_starrZ\x01\x00\x00X\t\x00\x00\x00ep_x_koelr[\x01\x00\x00X\t\x00\x00\x00ep_x_wolfr\\\x01\x00\x00X\x04\x00\x00\x00ep_xr]\x01\x00\x00X\x08\x00\x00\x00oracle_xr^\x01\x00\x00X\x06\x00\x00\x00cTiterr_\x01\x00\x00X\x08\x00\x00\x00cTiter_xr`\x01\x00\x00X\x07\x00\x00\x00ne_starra\x01\x00\x00X\x08\x00\x00\x00dms_starrb\x01\x00\x00X\x0e\x00\x00\x00dms_nonepitoperc\x01\x00\x00X\x0b\x00\x00\x00dms_entropyrd\x01\x00\x00X\x03\x00\x00\x00lbire\x01\x00\x00X\x0f\x00\x00\x00delta_frequencyrf\x01\x00\x00X\x0f\x00\x00\x00ep_star-ne_starrg\x01\x00\x00X\x0c\x00\x00\x00ep_x-ne_starrh\x01\x00\x00X\x0b\x00\x00\x00ne_star-lbiri\x01\x00\x00X\x10\x00\x00\x00cTiter_x-ne_starrj\x01\x00\x00X\x14\x00\x00\x00cTiter_x-ne_star-lbirk\x01\x00\x00eh\xe3Xh\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding/minimal_models_by_distances/ne_star-lbi.jsonrl\x01\x00\x00j\x12\x01\x00\x00]rm\x01\x00\x00(X\x05\x00\x00\x00naivern\x01\x00\x00X\x0b\x00\x00\x00ne_star-lbiro\x01\x00\x00X\x10\x00\x00\x00cTiter_x-ne_starrp\x01\x00\x00euX.\x00\x00\x00natural_sample_1_with_90_vpm_sliding_full_treerq\x01\x00\x00}rr\x01\x00\x00(h\x93X\x81\x00\x00\x00Full tree for very dense sampling of viruses over 25 years of H3N2 evolution after filtering outliers that don\'t match clock raters\x01\x00\x00h\xe7X\x1c\x00\x00\x00natural_sample_1_with_90_vpmrt\x01\x00\x00h\xcdXB\x00\x00\x00data/natural/natural_sample_1_with_90_vpm/filtered_sequences.fastaru\x01\x00\x00h\xcfX>\x00\x00\x00data/natural/natural_sample_1_with_90_vpm/strains_metadata.tsvrv\x01\x00\x00jS\x01\x00\x00X4\x00\x00\x00data/natural/natural_sample_1_with_90_vpm/titers.tsvrw\x01\x00\x00h\xb5X\n\x00\x00\x001990-10-01rx\x01\x00\x00h\xb7X\n\x00\x00\x002015-10-01ry\x01\x00\x00h\xd5K\x06h\xd6K\x19h\xd7K\x1eh\xd8X\x1b\x00\x00\x00config/reference_h3n2_ha.gbrz\x01\x00\x00h\xda]r{\x01\x00\x00X\x0b\x00\x00\x00ne_star-lbir|\x01\x00\x00ah\xe3Xh\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding/minimal_models_by_distances/ne_star-lbi.jsonr}\x01\x00\x00uX.\x00\x00\x00natural_sample_1_with_90_vpm_sliding_test_treer~\x01\x00\x00}r\x7f\x01\x00\x00(h\x93X\x81\x00\x00\x00Test data for very dense sampling of viruses over 25 years of H3N2 evolution after filtering outliers that don\'t match clock rater\x80\x01\x00\x00h\xe7X&\x00\x00\x00natural_sample_1_with_90_vpm_test_treer\x81\x01\x00\x00j%\x01\x00\x00X$\x00\x00\x00natural_sample_1_with_90_vpm_slidingr\x82\x01\x00\x00h\xfeX3\x00\x00\x00natural_sample_1_with_90_vpm_sliding_full_test_treer\x83\x01\x00\x00h\xcdXL\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/filtered_sequences.fastar\x84\x01\x00\x00h\xcfXH\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/strains_metadata.tsvr\x85\x01\x00\x00jS\x01\x00\x00X>\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/titers.tsvr\x86\x01\x00\x00h\xb5X\n\x00\x00\x002009-04-01r\x87\x01\x00\x00h\xb7X\n\x00\x00\x002019-10-01r\x88\x01\x00\x00h\xd5K\x06h\xd6K\x06h\xd7K\x06h\xd8X\x1b\x00\x00\x00config/reference_h3n2_ha.gbr\x89\x01\x00\x00h\xda]r\x8a\x01\x00\x00(X\x05\x00\x00\x00naiver\x8b\x01\x00\x00X\x07\x00\x00\x00ep_starr\x8c\x01\x00\x00X\t\x00\x00\x00ep_x_koelr\x8d\x01\x00\x00X\t\x00\x00\x00ep_x_wolfr\x8e\x01\x00\x00X\x04\x00\x00\x00ep_xr\x8f\x01\x00\x00X\x08\x00\x00\x00oracle_xr\x90\x01\x00\x00X\x06\x00\x00\x00cTiterr\x91\x01\x00\x00X\x08\x00\x00\x00cTiter_xr\x92\x01\x00\x00X\x07\x00\x00\x00ne_starr\x93\x01\x00\x00X\x08\x00\x00\x00dms_starr\x94\x01\x00\x00X\x0e\x00\x00\x00dms_nonepitoper\x95\x01\x00\x00X\x0b\x00\x00\x00dms_entropyr\x96\x01\x00\x00X\x03\x00\x00\x00lbir\x97\x01\x00\x00X\x0f\x00\x00\x00delta_frequencyr\x98\x01\x00\x00X\x0f\x00\x00\x00ep_star-ne_starr\x99\x01\x00\x00X\x0c\x00\x00\x00ep_x-ne_starr\x9a\x01\x00\x00X\x0b\x00\x00\x00ne_star-lbir\x9b\x01\x00\x00X\x10\x00\x00\x00cTiter_x-ne_starr\x9c\x01\x00\x00X\x14\x00\x00\x00cTiter_x-ne_star-lbir\x9d\x01\x00\x00eh\xe3Xm\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding/minimal_models_by_distances/cTiter_x-ne_star.jsonr\x9e\x01\x00\x00j\x12\x01\x00\x00]r\x9f\x01\x00\x00(X\x05\x00\x00\x00naiver\xa0\x01\x00\x00X\x0b\x00\x00\x00ne_star-lbir\xa1\x01\x00\x00X\x10\x00\x00\x00cTiter_x-ne_starr\xa2\x01\x00\x00euX3\x00\x00\x00natural_sample_1_with_90_vpm_sliding_full_test_treer\xa3\x01\x00\x00}r\xa4\x01\x00\x00(h\x93X\x8f\x00\x00\x00Full tree for test data for very dense sampling of viruses over 25 years of H3N2 evolution after filtering outliers that don\'t match clock rater\xa5\x01\x00\x00h\xe7X&\x00\x00\x00natural_sample_1_with_90_vpm_test_treer\xa6\x01\x00\x00h\xcdXL\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/filtered_sequences.fastar\xa7\x01\x00\x00h\xcfXH\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/strains_metadata.tsvr\xa8\x01\x00\x00jS\x01\x00\x00X>\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/titers.tsvr\xa9\x01\x00\x00h\xb5X\n\x00\x00\x002009-10-01r\xaa\x01\x00\x00h\xb7X\n\x00\x00\x002019-10-01r\xab\x01\x00\x00h\xd5K\x06h\xd6K\nh\xd7K\nh\xd8X\x1b\x00\x00\x00config/reference_h3n2_ha.gbr\xac\x01\x00\x00h\xda]r\xad\x01\x00\x00X\x0b\x00\x00\x00ne_star-lbir\xae\x01\x00\x00ah\xe3Xm\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding/minimal_models_by_distances/cTiter_x-ne_star.jsonr\xaf\x01\x00\x00uX\x17\x00\x00\x00natural_sample_20191001r\xb0\x01\x00\x00}r\xb1\x01\x00\x00(h\x93X\x83\x00\x00\x00Most recent build with very dense sampling of viruses to evaluate change in model coefficients during timepoints in the test periodr\xb2\x01\x00\x00h\xe7X&\x00\x00\x00natural_sample_1_with_90_vpm_test_treer\xb3\x01\x00\x00h\xcdXL\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/filtered_sequences.fastar\xb4\x01\x00\x00h\xcfXH\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/strains_metadata.tsvr\xb5\x01\x00\x00jS\x01\x00\x00X>\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/titers.tsvr\xb6\x01\x00\x00X\n\x00\x00\x00fra_titersr\xb7\x01\x00\x00XB\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/fra_titers.tsvr\xb8\x01\x00\x00h\xb5X\n\x00\x00\x002002-04-01r\xb9\x01\x00\x00h\xb7X\n\x00\x00\x002019-10-01r\xba\x01\x00\x00h\xd5K\x06h\xd6K\x06h\xd7K\x06h\xd8X\x1b\x00\x00\x00config/reference_h3n2_ha.gbr\xbb\x01\x00\x00h\xda]r\xbc\x01\x00\x00(X\x05\x00\x00\x00naiver\xbd\x01\x00\x00X\x14\x00\x00\x00fra_cTiter_x-ne_starr\xbe\x01\x00\x00X\x0b\x00\x00\x00ne_star-lbir\xbf\x01\x00\x00X\x10\x00\x00\x00cTiter_x-ne_starr\xc0\x01\x00\x00X\x14\x00\x00\x00cTiter_x-ne_star-lbir\xc1\x01\x00\x00eh\xe3Xm\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding/minimal_models_by_distances/cTiter_x-ne_star.jsonr\xc2\x01\x00\x00uuuX\r\x00\x00\x00path_to_faunar\xc3\x01\x00\x00X\x08\x00\x00\x00../faunar\xc4\x01\x00\x00X\x1a\x00\x00\x00years_for_titer_alignmentsr\xc5\x01\x00\x00K\nX\x12\x00\x00\x00min_tips_per_clader\xc6\x01\x00\x00K\x01X\x17\x00\x00\x00min_frequency_per_clader\xc7\x01\x00\x00G\x00\x00\x00\x00\x00\x00\x00\x00X\x0c\x00\x00\x00delta_pivotsr\xc8\x01\x00\x00K\x01X\x1a\x00\x00\x00months_for_distance_seasonr\xc9\x01\x00\x00K\x0cX\x1f\x00\x00\x00months_back_for_current_samplesr\xca\x01\x00\x00K\x06X\x17\x00\x00\x00max_years_for_distancesr\xcb\x01\x00\x00K\x05X\x1e\x00\x00\x00years_back_for_target_distancer\xcc\x01\x00\x00K\x03X\x19\x00\x00\x00target_distance_attributer\xcd\x01\x00\x00X\x07\x00\x00\x00hammingr\xce\x01\x00\x00jS\x01\x00\x00}r\xcf\x01\x00\x00(X\x08\x00\x00\x00passagesr\xd0\x01\x00\x00]r\xd1\x01\x00\x00X\x04\x00\x00\x00cellr\xd2\x01\x00\x00aX\x06\x00\x00\x00assaysr\xd3\x01\x00\x00]r\xd4\x01\x00\x00X\x02\x00\x00\x00hir\xd5\x01\x00\x00auh\xda]r\xd6\x01\x00\x00(X\x05\x00\x00\x00naiver\xd7\x01\x00\x00X\x03\x00\x00\x00lbir\xd8\x01\x00\x00X\x02\x00\x00\x00epr\xd9\x01\x00\x00X\x07\x00\x00\x00ep_starr\xda\x01\x00\x00X\x04\x00\x00\x00ep_xr\xdb\x01\x00\x00X\x06\x00\x00\x00cTiterr\xdc\x01\x00\x00X\t\x00\x00\x00cTiterSubr\xdd\x01\x00\x00X\x0e\x00\x00\x00cTiterSub_starr\xde\x01\x00\x00X\x0b\x00\x00\x00cTiterSub_xr\xdf\x01\x00\x00X\x0f\x00\x00\x00delta_frequencyr\xe0\x01\x00\x00X\x08\x00\x00\x00dms_starr\xe1\x01\x00\x00X\x07\x00\x00\x00ne_starr\xe2\x01\x00\x00X\x13\x00\x00\x00lbi-delta_frequencyr\xe3\x01\x00\x00X\x0b\x00\x00\x00lbi-ne_starr\xe4\x01\x00\x00X\x12\x00\x00\x00lbi-cTiter-ne_starr\xe5\x01\x00\x00X\x10\x00\x00\x00lbi-ep_x-ne_starr\xe6\x01\x00\x00eX\x14\x00\x00\x00predictors_simulatedr\xe7\x01\x00\x00]r\xe8\x01\x00\x00(X\x05\x00\x00\x00naiver\xe9\x01\x00\x00X\x07\x00\x00\x00fitnessr\xea\x01\x00\x00X\x03\x00\x00\x00lbir\xeb\x01\x00\x00X\x04\x00\x00\x00ep_xr\xec\x01\x00\x00X\x0f\x00\x00\x00delta_frequencyr\xed\x01\x00\x00X\x07\x00\x00\x00ne_starr\xee\x01\x00\x00X\x0c\x00\x00\x00ep_x-ne_starr\xef\x01\x00\x00X\x0b\x00\x00\x00lbi-ne_starr\xf0\x01\x00\x00X\x10\x00\x00\x00lbi-ep_x-ne_starr\xf1\x01\x00\x00eX\x0b\x00\x00\x00frequenciesr\xf2\x01\x00\x00}r\xf3\x01\x00\x00(X\x10\x00\x00\x00narrow_bandwidthr\xf4\x01\x00\x00G?\xc5Vl\xf4\x1f!-X\x0e\x00\x00\x00wide_bandwidthr\xf5\x01\x00\x00G?\xd0\x00\x00\x00\x00\x00\x00X\x0f\x00\x00\x00proportion_wider\xf6\x01\x00\x00G\x00\x00\x00\x00\x00\x00\x00\x00X\x0f\x00\x00\x00pivot_frequencyr\xf7\x01\x00\x00K\x06X\n\x00\x00\x00bandwidthsr\xf8\x01\x00\x00]r\xf9\x01\x00\x00(G?\x94z\xe1G\xae\x14{G?\xa4z\xe1G\xae\x14{G?\xb4z\xe1G\xae\x14{G?\xc4z\xe1G\xae\x14{G?\xd0\x00\x00\x00\x00\x00\x00G?\xd5\x1e\xb8Q\xeb\x85\x1fG?\xe0\x00\x00\x00\x00\x00\x00eX\x16\x00\x00\x00min_mutation_frequencyr\xfa\x01\x00\x00G\x00\x00\x00\x00\x00\x00\x00\x00X\t\x00\x00\x00stiffnessr\xfb\x01\x00\x00K\x14X\x07\x00\x00\x00inertiar\xfc\x01\x00\x00G?\xc9\x99\x99\x99\x99\x99\x9aX\x08\x00\x00\x00min_freqr\xfd\x01\x00\x00G?\x84z\xe1G\xae\x14{X\x10\x00\x00\x00preferred_methodr\xfe\x01\x00\x00X\x03\x00\x00\x00kder\xff\x01\x00\x00X\x17\x00\x00\x00max_years_for_diffusionr\x00\x02\x00\x00K\x02uX\x03\x00\x00\x00lbir\x01\x02\x00\x00}r\x02\x02\x00\x00(X\x03\x00\x00\x00taur\x03\x02\x00\x00G?\xd3333333X\x06\x00\x00\x00windowr\x04\x02\x00\x00G?\xe0\x00\x00\x00\x00\x00\x00uX\x19\x00\x00\x00excluded_node_data_fieldsr\x05\x02\x00\x00]r\x06\x02\x00\x00(X\x07\x00\x00\x00aa_mutsr\x07\x02\x00\x00X\x0c\x00\x00\x00aa_sequencesr\x08\x02\x00\x00X\x12\x00\x00\x00country_confidencer\t\x02\x00\x00X\x0b\x00\x00\x00ep_pairwiser\n\x02\x00\x00X\x12\x00\x00\x00cTiterSub_pairwiser\x0b\x02\x00\x00X\x12\x00\x00\x00ep_luksza_pairwiser\x0c\x02\x00\x00X\x13\x00\x00\x00ep_kratsch_pairwiser\r\x02\x00\x00X\x04\x00\x00\x00mutsr\x0e\x02\x00\x00X\x13\x00\x00\x00num_date_confidencer\x0f\x02\x00\x00X\x11\x00\x00\x00region_confidencer\x10\x02\x00\x00X\x08\x00\x00\x00sequencer\x11\x02\x00\x00eX\x0e\x00\x00\x00cross_immunityr\x12\x02\x00\x00}r\x13\x02\x00\x00X\x04\x00\x00\x00h3n2r\x14\x02\x00\x00}r\x15\x02\x00\x00X\x02\x00\x00\x00har\x16\x02\x00\x00}r\x17\x02\x00\x00(h\xc9}r\x18\x02\x00\x00(X\x13\x00\x00\x00distance_attributesr\x19\x02\x00\x00X\x0b\x00\x00\x00ep_pairwiser\x1a\x02\x00\x00X\x13\x00\x00\x00immunity_attributesr\x1b\x02\x00\x00X\x04\x00\x00\x00ep_xr\x1c\x02\x00\x00X\r\x00\x00\x00decay_factorsr\x1d\x02\x00\x00X\x04\x00\x00\x0014.0r\x1e\x02\x00\x00ujJ\x01\x00\x00}r\x1f\x02\x00\x00(j\x19\x02\x00\x00X=\x00\x00\x00ep_pairwise ep_pairwise_wolf ep_pairwise_koel oracle_pairwiser \x02\x00\x00j\x1b\x02\x00\x00X!\x00\x00\x00ep_x ep_x_wolf ep_x_koel oracle_xr!\x02\x00\x00j\x1d\x02\x00\x00X\x13\x00\x00\x0014.0 14.0 14.0 14.0r"\x02\x00\x00uussX\r\x00\x00\x00fitness_modelr#\x02\x00\x00}r$\x02\x00\x00(j\xfd\x01\x00\x00G?\x84z\xe1G\xae\x14{X\x08\x00\x00\x00max_freqr%\x02\x00\x00G?\xef\xae\x14z\xe1G\xaeX\x0f\x00\x00\x00training_windowr&\x02\x00\x00K\x06X\x13\x00\x00\x00delta_months_to_fitr\'\x02\x00\x00K\x0cX\x0c\x00\x00\x00delta_monthsr(\x02\x00\x00]r)\x02\x00\x00(K\x06K\x0ceX\x0f\x00\x00\x00primary_segmentr*\x02\x00\x00X\x02\x00\x00\x00har+\x02\x00\x00X\x13\x00\x00\x00clade_cost_functionr,\x02\x00\x00X\x10\x00\x00\x00information_gainr-\x02\x00\x00X\x16\x00\x00\x00distance_cost_functionr.\x02\x00\x00X\x07\x00\x00\x00diffsumr/\x02\x00\x00X\t\x00\x00\x00l1_lambdar0\x02\x00\x00G?\xb9\x99\x99\x99\x99\x99\x9aX\x0b\x00\x00\x00pseudocountr1\x02\x00\x00G?PbM\xd2\xf1\xa9\xfcuuX\x04\x00\x00\x00ruler2\x02\x00\x00X\x1d\x00\x00\x00figure_for_vaccine_comparisonr3\x02\x00\x00X\x0f\x00\x00\x00bench_iterationr4\x02\x00\x00NX\t\x00\x00\x00scriptdirr5\x02\x00\x00XB\x00\x00\x00/Users/jlhudd/projects/docker/flu-forecasting-submission/notebooksr6\x02\x00\x00ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir('/Users/jlhudd/projects/docker/flu-forecasting-submission');
######## snakemake preamble end #########

# %% [markdown]
# # Figure 8. Compare vaccine strains to estimated and observed closest strains to the future
#
# Observed distance to natural H3N2 populations one year into the future for each vaccine strain (green) and the observed (blue) and estimated (orange) closest strains to the future at the corresponding timepoints. Vaccine strains were assigned to the validation or test timepoint closest to the date they were selected by the WHO. The distance to the future of each vaccine strain was calculated from their amino acid sequences and the frequencies and sequences of the corresponding population one year in the future. The estimated closest strain to the future was identified by either the best model in the validation period (mutational load and LBI) or the best model in the test period
# (HI antigenic novelty and mutational load).

# %%
validation_tip_attributes_path = snakemake.input.validation_tip_attributes
test_tip_attributes_path = snakemake.input.test_tip_attributes

cTiter_x_ne_star_validation_forecasts_path = snakemake.input.cTiter_x_ne_star_validation_forecasts_path
ne_star_lbi_validation_forecasts_path = snakemake.input.ne_star_lbi_validation_forecasts_path
naive_validation_forecasts_path = snakemake.input.naive_validation_forecasts_path

cTiter_x_ne_star_test_forecasts_path = snakemake.input.cTiter_x_ne_star_test_forecasts_path
ne_star_lbi_test_forecasts_path = snakemake.input.ne_star_lbi_test_forecasts_path
naive_test_forecasts_path = snakemake.input.naive_test_forecasts_path

vaccines_json_path = snakemake.input.vaccines_json_path

output_figure = snakemake.output.figure
output_relative_figure = snakemake.output.relative_figure

# %%
"""
validation_tip_attributes_path = "../results/builds/natural/natural_sample_1_with_90_vpm_sliding/tip_attributes_with_weighted_distances.tsv"
validation_forecasts_path = "../results/builds/natural/natural_sample_1_with_90_vpm_sliding/forecasts.tsv"

test_tip_attributes_path = "../results/builds/natural/natural_sample_1_with_90_vpm_sliding_test_tree/tip_attributes_with_weighted_distances.tsv"
test_forecasts_path = "../results/builds/natural/natural_sample_1_with_90_vpm_sliding_test_tree/forecasts.tsv"

vaccines_json_path = "../config/vaccines_h3n2.json"

output_figure = "../manuscript/figures/vaccine-comparison.pdf"
"""
# Out:
# '\nvalidation_tip_attributes_path = "../results/builds/natural/natural_sample_1_with_90_vpm_sliding/tip_attributes_with_weighted_distances.tsv"\nvalidation_forecasts_path = "../results/builds/natural/natural_sample_1_with_90_vpm_sliding/forecasts.tsv"\n\ntest_tip_attributes_path = "../results/builds/natural/natural_sample_1_with_90_vpm_sliding_test_tree/tip_attributes_with_weighted_distances.tsv"\ntest_forecasts_path = "../results/builds/natural/natural_sample_1_with_90_vpm_sliding_test_tree/forecasts.tsv"\n\nvaccines_json_path = "../config/vaccines_h3n2.json"\n\noutput_figure = "../manuscript/figures/vaccine-comparison.pdf"\n'

# %%
import json
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import pandas as pd
from pandas.plotting import register_matplotlib_converters
from scipy.stats import pearsonr, spearmanr, probplot
import seaborn as sns
import statsmodels.api as sm

# %matplotlib inline

# %%
register_matplotlib_converters()

# %%
first_validation_timepoint = "2003-10-01"

# %%
sns.set_style("ticks")

# %%
# Display figures at a reasonable default size.
mpl.rcParams['figure.figsize'] = (6, 4)

# Disable top and right spines.
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.right'] = False
    
# Display and save figures at higher resolution for presentations and manuscripts.
mpl.rcParams['savefig.dpi'] = 200
mpl.rcParams['figure.dpi'] = 200

# Display text at sizes large enough for presentations and manuscripts.
mpl.rcParams['font.weight'] = "normal"
mpl.rcParams['axes.labelweight'] = "normal"
mpl.rcParams['font.size'] = 18
mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['legend.fontsize'] = 12
mpl.rcParams['xtick.labelsize'] = 14
mpl.rcParams['ytick.labelsize'] = 14

mpl.rc('text', usetex=False)

# %% [markdown]
# ## Define functions

# %%
def calculate_weighted_distance_between_pairs(row):
    distance = (
        np.frombuffer(row["aa_sequence"].encode(), dtype="S1") !=
        np.frombuffer(row["aa_sequence_future"].encode(), dtype="S1")
    ).sum()
    return row["frequency"] * distance

def calculate_weighted_distance_by_group(group_df):
    return group_df.apply(calculate_weighted_distance_between_pairs, axis=1).sum()

# %% [markdown]
# ## Load tip attributes with sequences
#
# For each timepoint, find distinct sequences that will be used to calculate distances to the future.

# %%
validation_tips_with_sequence = pd.read_csv(
    validation_tip_attributes_path,
    sep="\t",
    parse_dates=["timepoint"],
    usecols=["strain", "timepoint", "frequency", "aa_sequence"]
)

# %%
test_tips_with_sequence = pd.read_csv(
    test_tip_attributes_path,
    sep="\t",
    parse_dates=["timepoint"],
    usecols=["strain", "timepoint", "frequency", "aa_sequence"]
)

# %%
# Retain only validation tips whose timepoints occur prior to the first
# test timepoint. This prevents us from using too many tips from overlapping
# timepoints between validation and test periods.
validation_tips_with_sequence = validation_tips_with_sequence[
    (validation_tips_with_sequence["timepoint"] < test_tips_with_sequence["timepoint"].min()) &
    (validation_tips_with_sequence["timepoint"] >= first_validation_timepoint)
].copy()

# %%
last_validation_timepoint = validation_tips_with_sequence["timepoint"].max()

# %%
last_validation_timepoint
# Out:
# Timestamp('2014-10-01 00:00:00')

# %%
distinct_validation_tips_with_sequence = validation_tips_with_sequence.groupby(
    ["timepoint", "aa_sequence"]
).first().reset_index()

# %%
distinct_test_tips_with_sequence = test_tips_with_sequence.groupby(
    ["timepoint", "aa_sequence"]
).first().reset_index()

# %%
tips_with_sequence = pd.concat([validation_tips_with_sequence, test_tips_with_sequence])

# %%
distinct_tips_with_sequence = pd.concat([distinct_validation_tips_with_sequence, distinct_test_tips_with_sequence])

# %% [markdown]
# ## Load vaccine strain data
#
# Load information about vaccine strains including their names, amino acid sequences, and the timepoint in our analysis when they were selected for the vaccine. These latter timepoints constrain the timepoints we consider in the analyses that follow.

# %%
with open(vaccines_json_path, "r") as fh:
    vaccines_json = json.load(fh)

# %%
vaccine_df = pd.DataFrame([
    {
        "strain_type": "vaccine",
        "strain": vaccine,
        "timepoint": vaccine_data["vaccine"]["timepoint"],
        "aa_sequence": vaccine_data["aa_sequence"],
        "abbreviation": vaccine_data["vaccine"]["abbreviation"]
    }
    for vaccine, vaccine_data in vaccines_json["nodes"].items()
])
vaccine_df["timepoint"] = pd.to_datetime(vaccine_df["timepoint"])
vaccine_df["future_timepoint"] = vaccine_df["timepoint"] + pd.DateOffset(months=12)

# %%
# Find all tips with sequences at the future timepoint for each vaccine strain.
tips_for_vaccines_df = vaccine_df.merge(
    tips_with_sequence,
    left_on=["future_timepoint"],
    right_on=["timepoint"],
    suffixes=["", "_future"]
)

# %%
vaccine_distance_to_future = tips_for_vaccines_df.groupby("timepoint").apply(
    calculate_weighted_distance_by_group
).reset_index(name="distance_to_future")

# %%
vaccine_forecasts = vaccine_df.merge(
    vaccine_distance_to_future,
    on="timepoint"
).loc[:, ["strain_type", "strain", "abbreviation", "timepoint", "future_timepoint", "distance_to_future"]]

# %%
vaccine_forecasts
# Out:
#    strain_type                           strain abbreviation  timepoint  \
# 0      vaccine                A/Fujian/411/2002         FU02 2003-10-01
# 1      vaccine              A/Wellington/1/2004         WE04 2004-10-01
# 2      vaccine              A/California/7/2004         CA04 2005-04-01
# 3      vaccine              A/Wisconsin/67/2005         WI05 2006-04-01
# 4      vaccine               A/Brisbane/10/2007         BR07 2007-10-01
# 5      vaccine                  A/Perth/16/2009         PE09 2009-10-01
# 6      vaccine              A/Victoria/361/2011         VI11 2012-04-01
# 7      vaccine                  A/Texas/50/2012         TX12 2013-10-01
# 8      vaccine       A/Switzerland/9715293/2013         SW13 2014-10-01
# 9      vaccine             A/HongKong/4801/2014         HK14 2015-10-01
# 10     vaccine  A/Singapore/Infimh-16-0019/2016         SI16 2017-10-01
# 11     vaccine          A/Switzerland/8060/2017         SW17 2018-10-01
#
# ...

# %% [markdown]
# ## Load forecasts from models

# %% [markdown]
# ### Load forecasts from mutational load and LBI model

# %%
ne_star_lbi_validation_forecasts = pd.read_csv(
    ne_star_lbi_validation_forecasts_path,
    sep="\t",
    parse_dates=["timepoint", "future_timepoint"]
)

# %%
ne_star_lbi_validation_forecasts = ne_star_lbi_validation_forecasts.query(
    "timepoint >= '%s'" % first_validation_timepoint
).dropna().copy()

# %%
ne_star_lbi_test_forecasts = pd.read_csv(
    ne_star_lbi_test_forecasts_path,
    sep="\t",
    parse_dates=["timepoint", "future_timepoint"]
).dropna()

# %%
ne_star_lbi_forecasts = pd.concat([
    ne_star_lbi_validation_forecasts,
    ne_star_lbi_test_forecasts
])
ne_star_lbi_forecasts = ne_star_lbi_forecasts[
    ne_star_lbi_forecasts["timepoint"].isin(vaccine_forecasts["timepoint"])
].copy()

# %% [markdown]
# ### Load forecasts from HI antigenic novelty and mutational load model

# %%
cTiter_x_ne_star_validation_forecasts = pd.read_csv(
    cTiter_x_ne_star_validation_forecasts_path,
    sep="\t",
    parse_dates=["timepoint", "future_timepoint"]
)

# %%
cTiter_x_ne_star_validation_forecasts = cTiter_x_ne_star_validation_forecasts.query(
    "timepoint >= '%s'" % first_validation_timepoint
).dropna().copy()

# %%
cTiter_x_ne_star_test_forecasts = pd.read_csv(
    cTiter_x_ne_star_test_forecasts_path,
    sep="\t",
    parse_dates=["timepoint", "future_timepoint"]
).dropna()

# %%
cTiter_x_ne_star_forecasts = pd.concat([
    cTiter_x_ne_star_validation_forecasts,
    cTiter_x_ne_star_test_forecasts
])
cTiter_x_ne_star_forecasts = cTiter_x_ne_star_forecasts[
    cTiter_x_ne_star_forecasts["timepoint"].isin(vaccine_forecasts["timepoint"])
].copy()

# %% [markdown]
# ### Load forecasts from naive model

# %%
naive_validation_forecasts = pd.read_csv(
    naive_validation_forecasts_path,
    sep="\t",
    parse_dates=["timepoint", "future_timepoint"]
)

# %%
naive_validation_forecasts = naive_validation_forecasts.query(
    "timepoint >= '%s'" % first_validation_timepoint
).dropna().copy()

# %%
naive_test_forecasts = pd.read_csv(
    naive_test_forecasts_path,
    sep="\t",
    parse_dates=["timepoint", "future_timepoint"]
).dropna()

# %%
naive_forecasts = pd.concat([
    naive_validation_forecasts,
    naive_test_forecasts
])
naive_forecasts = naive_forecasts[
    naive_forecasts["timepoint"].isin(vaccine_forecasts["timepoint"])
].copy()

# %% [markdown]
# ## Identify observed closest strains to the future
#
# Use strains from forecast models with annotated weighted distances to the future to find observed closest strains to the future per timepoint with a vaccine.

# %%
combined_forecasts = pd.concat([
    ne_star_lbi_forecasts,
    cTiter_x_ne_star_forecasts
])

# %%
observed_closest_strains = combined_forecasts.sort_values(["timepoint", "weighted_distance_to_future"]).groupby(
    "timepoint"
).first().reset_index().loc[:, ["timepoint", "future_timepoint", "strain", "weighted_distance_to_future"]]
observed_closest_strains["strain_type"] = "observed closest"
observed_closest_strains = observed_closest_strains.rename(
    columns={"weighted_distance_to_future": "distance_to_future"}
)

# %%
observed_closest_strains["relative_distance_to_future"] = (
    observed_closest_strains["distance_to_future"] - vaccine_forecasts["distance_to_future"]
)

# %%
observed_closest_strains
# Out:
#     timepoint future_timepoint                         strain  \
# 0  2003-10-01       2004-10-01              A/Jiangxi/20/2003
# 1  2004-10-01       2005-10-01             A/Jeonnam/336/2004
# 2  2005-04-01       2006-04-01          A/Malaysia/31944/2005
# 3  2006-04-01       2007-04-01           A/England/61007/2006
# 4  2007-10-01       2008-10-01             A/Hanoi/BM238/2007
# 5  2009-10-01       2010-10-01    A/BadenWurttemberg/209/2009
# 6  2012-04-01       2013-04-01         A/Anhui-Jinan/173/2012
# 7  2013-10-01       2014-10-01      A/AmericanSamoa/4796/2013
# 8  2014-10-01       2015-10-01           A/Asturias/1949/2014
# 9  2015-10-01       2016-10-01              A/Brazil/187/2015
# 10 2017-10-01       2018-10-01            A/Ayutthaya/73/2017
# 11 2018-10-01       2019-10-01  A/Shanghai-Huangpu/11325/2018
#
#     distance_to_future       strain_type  relative_distance_to_future
# 0             4.077711  observed closest                    -5.364816
# ...

# %% [markdown]
# ## Identify estimated closest strains to the future by model
#
# Use strains from forecast models with annotated weighted distances to the future to find estimated closest strains to the future per timepoint with a vaccine.

# %% [markdown]
# ### Identify estimated closest strains to the future by mutational load and LBI

# %%
estimated_closest_strains_by_ne_star_lbi = ne_star_lbi_forecasts.sort_values(
    ["timepoint", "y"]
).groupby(
    "timepoint"
).first().reset_index().loc[:, ["timepoint", "future_timepoint", "strain", "weighted_distance_to_future"]]
estimated_closest_strains_by_ne_star_lbi["strain_type"] = "estimated closest by ne_star-lbi"
estimated_closest_strains_by_ne_star_lbi = estimated_closest_strains_by_ne_star_lbi.rename(
    columns={"weighted_distance_to_future": "distance_to_future"}
)

# %%
estimated_closest_strains_by_ne_star_lbi["relative_distance_to_future"] = (
    estimated_closest_strains_by_ne_star_lbi["distance_to_future"] - vaccine_forecasts["distance_to_future"]
)

# %%
estimated_closest_strains_by_ne_star_lbi
# Out:
#     timepoint future_timepoint                     strain  distance_to_future  \
# 0  2003-10-01       2004-10-01  A/Australia/NHRC0001/2003            8.435527
# 1  2004-10-01       2005-10-01            A/Dakar/18/2004            4.378632
# 2  2005-04-01       2006-04-01      A/Austria/212187/2005            4.601412
# 3  2006-04-01       2007-04-01  A/Canada/CN-RV657-06/2006            5.363311
# 4  2007-10-01       2008-10-01            A/Aichi/67/2007            3.784125
# 5  2009-10-01       2010-10-01           A/Morobe/10/2009            6.946014
# 6  2012-04-01       2013-04-01           A/Aichi/233/2011            3.723947
# 7  2013-10-01       2014-10-01          A/Chiba-C/44/2013            6.539906
# 8  2014-10-01       2015-10-01     A/Bangladesh/2008/2014            3.882022
# 9  2015-10-01       2016-10-01           A/Arizona/7/2015            7.326317
# 10 2017-10-01       2018-10-01            A/Akita/21/2017            7.467113
# ...

# %% [markdown]
# ### Identify estimated closest strains to the future by HI antigenic novelty and mutational load

# %%
estimated_closest_strains_by_cTiter_x_ne_star = cTiter_x_ne_star_forecasts.sort_values(
    ["timepoint", "y"]
).groupby(
    "timepoint"
).first().reset_index().loc[:, ["timepoint", "future_timepoint", "strain", "weighted_distance_to_future"]]
estimated_closest_strains_by_cTiter_x_ne_star["strain_type"] = "estimated closest by cTiter_x-ne_star"
estimated_closest_strains_by_cTiter_x_ne_star = estimated_closest_strains_by_cTiter_x_ne_star.rename(
    columns={"weighted_distance_to_future": "distance_to_future"}
)

# %%
estimated_closest_strains_by_cTiter_x_ne_star["relative_distance_to_future"] = (
    estimated_closest_strains_by_cTiter_x_ne_star["distance_to_future"] - vaccine_forecasts["distance_to_future"]
)

# %%
estimated_closest_strains_by_cTiter_x_ne_star
# Out:
#     timepoint future_timepoint                  strain  distance_to_future  \
# 0  2003-10-01       2004-10-01      A/Hanoi/BM766/2003            6.497199
# 1  2004-10-01       2005-10-01         A/Dakar/18/2004            4.378632
# 2  2005-04-01       2006-04-01   A/Austria/212187/2005            4.601412
# 3  2006-04-01       2007-04-01   A/Anhui-Baohe/10/2005            5.368142
# 4  2007-10-01       2008-10-01         A/Aichi/67/2007            3.784125
# 5  2009-10-01       2010-10-01        A/Aichi/689/2009            7.932002
# 6  2012-04-01       2013-04-01        A/Alaska/17/2011            7.016824
# 7  2013-10-01       2014-10-01        A/Alabama/7/2013            6.890131
# 8  2014-10-01       2015-10-01  A/Bangladesh/2008/2014            3.882022
# 9  2015-10-01       2016-10-01       A/Alaska/115/2015            6.085611
# 10 2017-10-01       2018-10-01    A/Philippines/7/2017            7.812084
# ...

# %% [markdown]
# ### Identify estimated closest strains to the future by naive model

# %%
estimated_closest_strains_by_naive = naive_forecasts.sort_values(
    ["timepoint", "y"]
).groupby(
    "timepoint"
).first().reset_index().loc[:, ["timepoint", "future_timepoint", "strain", "weighted_distance_to_future"]]
estimated_closest_strains_by_naive["strain_type"] = "estimated closest by naive"
estimated_closest_strains_by_naive = estimated_closest_strains_by_naive.rename(
    columns={"weighted_distance_to_future": "distance_to_future"}
)

# %%
estimated_closest_strains_by_naive["relative_distance_to_future"] = (
    estimated_closest_strains_by_naive["distance_to_future"] - vaccine_forecasts["distance_to_future"]
)

# %%
estimated_closest_strains_by_naive
# Out:
#     timepoint future_timepoint                     strain  distance_to_future  \
# 0  2003-10-01       2004-10-01      A/Malaysia/25849/2003            7.491835
# 1  2004-10-01       2005-10-01            A/Dakar/18/2004            4.378632
# 2  2005-04-01       2006-04-01      A/Austria/212187/2005            4.601412
# 3  2006-04-01       2007-04-01      A/Anhui-Baohe/10/2005            5.368142
# 4  2007-10-01       2008-10-01     A/Honduras/AF1426/2007            3.800517
# 5  2009-10-01       2010-10-01           A/Morobe/10/2009            6.946014
# 6  2012-04-01       2013-04-01          A/Alborz/927/2012            6.118127
# 7  2013-10-01       2014-10-01  A/AmericanSamoa/4796/2013            5.435997
# 8  2014-10-01       2015-10-01          A/Austria/96/2014            9.819486
# 9  2015-10-01       2016-10-01          A/Alaska/115/2015            6.085611
# 10 2017-10-01       2018-10-01       A/Philippines/7/2017            7.812084
# ...

# %% [markdown]
# ## Plot distance to the future by timepoint and strain type
#
# Compare distances to the future for selected vaccine strains and the observed and estimated closest strains to the future.

# %%
colors_by_strain_type = {
    "vaccine strain": "#2ca02c",
    "observed best": "#1f77b4",
    "estimated best by ne_star-lbi": "#ff7f0e",
    "estimated best by cTiter_x-ne_star": "#9467bd",
    "estimated best by naive": "#999999",
}

# %% [markdown]
# Split data frames into validation and test periods.

# %%
observed_closest_strains_for_validation = observed_closest_strains[
    observed_closest_strains["timepoint"] <= last_validation_timepoint
]
estimated_closest_strains_by_cTiter_x_ne_star_for_validation = estimated_closest_strains_by_cTiter_x_ne_star[
    estimated_closest_strains_by_cTiter_x_ne_star["timepoint"] <= last_validation_timepoint
]
estimated_closest_strains_by_ne_star_lbi_for_validation = estimated_closest_strains_by_ne_star_lbi[
    estimated_closest_strains_by_ne_star_lbi["timepoint"] <= last_validation_timepoint
]
estimated_closest_strains_by_naive_for_validation = estimated_closest_strains_by_naive[
    estimated_closest_strains_by_naive["timepoint"] <= last_validation_timepoint
]
vaccine_forecasts_for_validation = vaccine_forecasts[
    vaccine_forecasts["timepoint"] <= last_validation_timepoint
]

# %%
observed_closest_strains_for_test = observed_closest_strains[
    observed_closest_strains["timepoint"] > last_validation_timepoint
]
estimated_closest_strains_by_cTiter_x_ne_star_for_test = estimated_closest_strains_by_cTiter_x_ne_star[
    estimated_closest_strains_by_cTiter_x_ne_star["timepoint"] > last_validation_timepoint
]
estimated_closest_strains_by_ne_star_lbi_for_test = estimated_closest_strains_by_ne_star_lbi[
    estimated_closest_strains_by_ne_star_lbi["timepoint"] > last_validation_timepoint
]
estimated_closest_strains_by_naive_for_test = estimated_closest_strains_by_naive[
    estimated_closest_strains_by_naive["timepoint"] > last_validation_timepoint
]
vaccine_forecasts_for_test = vaccine_forecasts[
    vaccine_forecasts["timepoint"] > last_validation_timepoint
]

# %%
max_distance_to_future = max(
    observed_closest_strains["distance_to_future"].max(),
    estimated_closest_strains_by_ne_star_lbi["distance_to_future"].max(),
    estimated_closest_strains_by_cTiter_x_ne_star["distance_to_future"].max(),
    estimated_closest_strains_by_naive["distance_to_future"].max(),
    vaccine_forecasts["distance_to_future"].max()
)

# %%
max_distance_to_future
# Out:
# 17.078473000000006

# %%
distance_ticks = np.arange(int(np.ceil(max_distance_to_future)) + 2, step=2)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 3.5))
#ax = axes[0]

strain_alpha=0.5

# Plot validation results.
ax.plot(
    estimated_closest_strains_by_naive_for_validation["timepoint"],
    estimated_closest_strains_by_naive_for_validation["distance_to_future"],
    "o-",
    color=colors_by_strain_type["estimated best by naive"],
    alpha=strain_alpha,
    label="estimated best by naive"
)

ax.plot(
    estimated_closest_strains_by_cTiter_x_ne_star_for_validation["timepoint"],
    estimated_closest_strains_by_cTiter_x_ne_star_for_validation["distance_to_future"],
    "o-",
    color=colors_by_strain_type["estimated best by cTiter_x-ne_star"],
    alpha=strain_alpha,
    label="estimated best by HI + mutational load"
)

ax.plot(
    estimated_closest_strains_by_ne_star_lbi_for_validation["timepoint"],
    estimated_closest_strains_by_ne_star_lbi_for_validation["distance_to_future"],
    "o-",
    color=colors_by_strain_type["estimated best by ne_star-lbi"],
    alpha=strain_alpha,
    label="estimated best by mutational load + LBI"
)

ax.plot(
    observed_closest_strains_for_validation["timepoint"],
    observed_closest_strains_for_validation["distance_to_future"],
    "o-",
    color=colors_by_strain_type["observed best"],
    alpha=strain_alpha,
    label="observed best"
)

ax.plot(
    vaccine_forecasts_for_validation["timepoint"],
    vaccine_forecasts_for_validation["distance_to_future"],
    "o-",
    color=colors_by_strain_type["vaccine strain"],
    alpha=strain_alpha,
    label="vaccine strain"
)

# Plot test results.
ax.plot(
    estimated_closest_strains_by_naive_for_test["timepoint"],
    estimated_closest_strains_by_naive_for_test["distance_to_future"],
    "o-",
    color=colors_by_strain_type["estimated best by naive"],
    alpha=strain_alpha
)

ax.plot(
    estimated_closest_strains_by_cTiter_x_ne_star_for_test["timepoint"],
    estimated_closest_strains_by_cTiter_x_ne_star_for_test["distance_to_future"],
    "o-",
    color=colors_by_strain_type["estimated best by cTiter_x-ne_star"],
    alpha=strain_alpha
)

ax.plot(
    estimated_closest_strains_by_ne_star_lbi_for_test["timepoint"],
    estimated_closest_strains_by_ne_star_lbi_for_test["distance_to_future"],
    "o-",
    color=colors_by_strain_type["estimated best by ne_star-lbi"],
    alpha=strain_alpha
)

ax.plot(
    observed_closest_strains_for_test["timepoint"],
    observed_closest_strains_for_test["distance_to_future"],
    "o-",
    color=colors_by_strain_type["observed best"],
    alpha=strain_alpha
)

ax.plot(
    vaccine_forecasts_for_test["timepoint"],
    vaccine_forecasts_for_test["distance_to_future"],
    "o-",
    color=colors_by_strain_type["vaccine strain"],
    alpha=strain_alpha
)

for index, record in vaccine_forecasts.iterrows():
    ax.text(
        record["timepoint"],
        record["distance_to_future"] + 0.3,
        record["abbreviation"],
        fontsize=10,
        horizontalalignment="center"
    )

ax.axvline(
    last_validation_timepoint,
    ymax=0.75,
    zorder=-10,
    alpha=0.2,
    color="#000000",
    linestyle="-",
    label="Last validation timepoint"
)

ax.legend(
    loc=(0.01, 0.75),
    frameon=False,
    fontsize=10,
    ncol=2
)

ax.set_yticks(distance_ticks)

ax.set_xlabel("Date")
ax.set_ylabel("Weighted distance\nto the future (AAs)")
ax.set_ylim(bottom=0)

plt.tight_layout()
plt.savefig(output_figure, bbox_inches="tight")

# %%
vaccine_forecasts
# Out:
#    strain_type                           strain abbreviation  timepoint  \
# 0      vaccine                A/Fujian/411/2002         FU02 2003-10-01
# 1      vaccine              A/Wellington/1/2004         WE04 2004-10-01
# 2      vaccine              A/California/7/2004         CA04 2005-04-01
# 3      vaccine              A/Wisconsin/67/2005         WI05 2006-04-01
# 4      vaccine               A/Brisbane/10/2007         BR07 2007-10-01
# 5      vaccine                  A/Perth/16/2009         PE09 2009-10-01
# 6      vaccine              A/Victoria/361/2011         VI11 2012-04-01
# 7      vaccine                  A/Texas/50/2012         TX12 2013-10-01
# 8      vaccine       A/Switzerland/9715293/2013         SW13 2014-10-01
# 9      vaccine             A/HongKong/4801/2014         HK14 2015-10-01
# 10     vaccine  A/Singapore/Infimh-16-0019/2016         SI16 2017-10-01
# 11     vaccine          A/Switzerland/8060/2017         SW17 2018-10-01
#
# ...

# %% [markdown]
# Plot the distance to the future for each model relative to the vaccine strain. This view provides a better sense of how much closer to the future an estimated best strain is than the selected vaccine strain.

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 3.5))
#ax = axes[0]

strain_alpha=0.5

# Plot validation results.
ax.plot(
    estimated_closest_strains_by_naive_for_validation["timepoint"],
    estimated_closest_strains_by_naive_for_validation["relative_distance_to_future"],
    "o-",
    color=colors_by_strain_type["estimated best by naive"],
    alpha=strain_alpha,
    label="estimated best by naive"
)

ax.plot(
    estimated_closest_strains_by_cTiter_x_ne_star_for_validation["timepoint"],
    estimated_closest_strains_by_cTiter_x_ne_star_for_validation["relative_distance_to_future"],
    "o-",
    color=colors_by_strain_type["estimated best by cTiter_x-ne_star"],
    alpha=strain_alpha,
    label="estimated best by HI + mutational load"
)

ax.plot(
    estimated_closest_strains_by_ne_star_lbi_for_validation["timepoint"],
    estimated_closest_strains_by_ne_star_lbi_for_validation["relative_distance_to_future"],
    "o-",
    color=colors_by_strain_type["estimated best by ne_star-lbi"],
    alpha=strain_alpha,
    label="estimated best by mutational load + LBI"
)

ax.plot(
    observed_closest_strains_for_validation["timepoint"],
    observed_closest_strains_for_validation["relative_distance_to_future"],
    "o-",
    color=colors_by_strain_type["observed best"],
    alpha=strain_alpha,
    label="observed best"
)

# Plot test results.
ax.plot(
    estimated_closest_strains_by_naive_for_test["timepoint"],
    estimated_closest_strains_by_naive_for_test["relative_distance_to_future"],
    "o-",
    color=colors_by_strain_type["estimated best by naive"],
    alpha=strain_alpha
)

ax.plot(
    estimated_closest_strains_by_cTiter_x_ne_star_for_test["timepoint"],
    estimated_closest_strains_by_cTiter_x_ne_star_for_test["relative_distance_to_future"],
    "o-",
    color=colors_by_strain_type["estimated best by cTiter_x-ne_star"],
    alpha=strain_alpha
)

ax.plot(
    estimated_closest_strains_by_ne_star_lbi_for_test["timepoint"],
    estimated_closest_strains_by_ne_star_lbi_for_test["relative_distance_to_future"],
    "o-",
    color=colors_by_strain_type["estimated best by ne_star-lbi"],
    alpha=strain_alpha
)

ax.plot(
    observed_closest_strains_for_test["timepoint"],
    observed_closest_strains_for_test["relative_distance_to_future"],
    "o-",
    color=colors_by_strain_type["observed best"],
    alpha=strain_alpha
)

ax.axhline(
    y=0,
    color="#000000",
    zorder=-10,
    lw=0.75
)

ax.axvline(
    last_validation_timepoint,
    ymax=0.8,
    zorder=-10,
    alpha=0.2,
    color="#000000",
    linestyle="-",
    label="Last validation timepoint"
)

ax.legend(
    loc=(0.01, 0.75),
    frameon=False,
    fontsize=10,
    ncol=2
)

#ax.set_yticks(distance_ticks)

ax.set_xlabel("Date")
ax.set_ylabel("Weighted distance\nto the future (AAs)\nrelative to vaccine strain")
ax.set_ylim(-8, 3)

plt.tight_layout()
plt.savefig(output_relative_figure, bbox_inches="tight")

# %%
merged_model_and_vaccine_ne_star_lbi = vaccine_forecasts.merge(
    estimated_closest_strains_by_ne_star_lbi,
    on=["timepoint"],
    suffixes=["_vaccine", "_model"]
)

# %%
merged_model_and_vaccine_ne_star_lbi["vaccine_minus_model"] = (
    merged_model_and_vaccine_ne_star_lbi["distance_to_future_vaccine"] - 
    merged_model_and_vaccine_ne_star_lbi["distance_to_future_model"]
)

# %%
merged_model_and_vaccine_ne_star_lbi["vaccine_minus_model"]
# Out:
# 0     1.007000
# 1     1.699958
# 2     2.894438
# 3     4.941565
# 4     1.999962
# 5     1.004941
# 6     2.541889
# 7     2.110323
# 8     6.942614
# 9    -1.240706
# 10    1.146931
# 11   -1.913147
# Name: vaccine_minus_model, dtype: float64

# %%
(merged_model_and_vaccine_ne_star_lbi["vaccine_minus_model"] < 0).sum()
# Out:
# 2

# %%
merged_model_and_vaccine_ne_star_lbi[
    merged_model_and_vaccine_ne_star_lbi["vaccine_minus_model"] < 0
]["vaccine_minus_model"].mean()
# Out:
# -1.5769265000000021

# %%
merged_model_and_vaccine_ne_star_lbi["vaccine_minus_model"].mean()
# Out:
# 1.9279806666666657

# %%
merged_model_and_vaccine_cTiter_x_ne_star = vaccine_forecasts.merge(
    estimated_closest_strains_by_cTiter_x_ne_star,
    on=["timepoint"],
    suffixes=["_vaccine", "_model"]
)

# %%
merged_model_and_vaccine_cTiter_x_ne_star["vaccine_minus_model"] = (
    merged_model_and_vaccine_cTiter_x_ne_star["distance_to_future_vaccine"] -
    merged_model_and_vaccine_cTiter_x_ne_star["distance_to_future_model"]
)

# %%
merged_model_and_vaccine_cTiter_x_ne_star["vaccine_minus_model"]
# Out:
# 0     2.945328e+00
# 1     1.699958e+00
# 2     2.894438e+00
# 3     4.936734e+00
# 4     1.999962e+00
# 5     1.895300e-02
# 6    -7.509880e-01
# 7     1.760098e+00
# 8     6.942614e+00
# 9     8.881784e-16
# 10    8.019600e-01
# 11    4.746683e+00
# Name: vaccine_minus_model, dtype: float64

# %%
(merged_model_and_vaccine_cTiter_x_ne_star["vaccine_minus_model"] < 0).sum()
# Out:
# 1

# %%
merged_model_and_vaccine_cTiter_x_ne_star[
    merged_model_and_vaccine_cTiter_x_ne_star["vaccine_minus_model"] < 0
]["vaccine_minus_model"]
# Out:
# 6   -0.750988
# Name: vaccine_minus_model, dtype: float64

# %%
merged_model_and_vaccine_cTiter_x_ne_star["vaccine_minus_model"].mean()
# Out:
# 2.332978333333334

# %%
merged_model_and_vaccine_naive = vaccine_forecasts.merge(
    estimated_closest_strains_by_naive,
    on=["timepoint"],
    suffixes=["_vaccine", "_model"]
)

# %%
merged_model_and_vaccine_naive["vaccine_minus_model"] = (
    merged_model_and_vaccine_naive["distance_to_future_vaccine"] -
    merged_model_and_vaccine_naive["distance_to_future_model"]
)

# %%
merged_model_and_vaccine_naive["vaccine_minus_model"]
# Out:
# 0     1.950692e+00
# 1     1.699958e+00
# 2     2.894438e+00
# 3     4.936734e+00
# 4     1.983570e+00
# 5     1.004941e+00
# 6     1.477090e-01
# 7     3.214232e+00
# 8     1.005150e+00
# 9     8.881784e-16
# 10    8.019600e-01
# 11    6.684818e+00
# Name: vaccine_minus_model, dtype: float64

# %%
(merged_model_and_vaccine_naive["vaccine_minus_model"] < 0).sum()
# Out:
# 0

# %%
merged_model_and_vaccine_naive["vaccine_minus_model"].mean()
# Out:
# 2.1936834999999983
