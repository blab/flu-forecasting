# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/Users/jlhudd/miniconda3/envs/nextstrain/lib/python3.6/site-packages', '/Users/jlhudd/projects/docker/flu-forecasting/notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x03csnakemake.script\nSnakemake\nq\x00)\x81q\x01}q\x02(X\x05\x00\x00\x00inputq\x03csnakemake.io\nInputFiles\nq\x04)\x81q\x05(Xf\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding/tip_attributes_with_weighted_distances.tsvq\x06Xp\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding_test_tree/tip_attributes_with_weighted_distances.tsvq\x07XZ\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding/forecasts_cTiter_x-ne_star.tsvq\x08XU\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding/forecasts_ne_star-lbi.tsvq\tXd\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding_test_tree/forecasts_cTiter_x-ne_star.tsvq\nX_\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding_test_tree/forecasts_ne_star-lbi.tsvq\x0bX\x19\x00\x00\x00config/vaccines_h3n2.jsonq\x0ce}q\r(X\x06\x00\x00\x00_namesq\x0e}q\x0f(X\x19\x00\x00\x00validation_tip_attributesq\x10K\x00N\x86q\x11X\x13\x00\x00\x00test_tip_attributesq\x12K\x01N\x86q\x13X*\x00\x00\x00cTiter_x_ne_star_validation_forecasts_pathq\x14K\x02N\x86q\x15X%\x00\x00\x00ne_star_lbi_validation_forecasts_pathq\x16K\x03N\x86q\x17X$\x00\x00\x00cTiter_x_ne_star_test_forecasts_pathq\x18K\x04N\x86q\x19X\x1f\x00\x00\x00ne_star_lbi_test_forecasts_pathq\x1aK\x05N\x86q\x1bX\x12\x00\x00\x00vaccines_json_pathq\x1cK\x06N\x86q\x1duX\x12\x00\x00\x00_allowed_overridesq\x1e]q\x1f(X\x05\x00\x00\x00indexq X\x04\x00\x00\x00sortq!eh cfunctools\npartial\nq"cbuiltins\ngetattr\nq#csnakemake.io\nNamedlist\nq$X\x0f\x00\x00\x00_used_attributeq%\x86q&Rq\'\x85q(Rq)(h\')}q*X\x05\x00\x00\x00_nameq+h sNtq,bh!h"h\'\x85q-Rq.(h\')}q/h+h!sNtq0bh\x10h\x06h\x12h\x07h\x14h\x08h\x16h\th\x18h\nh\x1ah\x0bh\x1ch\x0cubX\x06\x00\x00\x00outputq1csnakemake.io\nOutputFiles\nq2)\x81q3X)\x00\x00\x00manuscript/figures/vaccine-comparison.pdfq4a}q5(h\x0e}q6X\x06\x00\x00\x00figureq7K\x00N\x86q8sh\x1e]q9(h h!eh h"h\'\x85q:Rq;(h\')}q<h+h sNtq=bh!h"h\'\x85q>Rq?(h\')}q@h+h!sNtqAbh7h4ubX\x06\x00\x00\x00paramsqBcsnakemake.io\nParams\nqC)\x81qD}qE(h\x0e}qFh\x1e]qG(h h!eh h"h\'\x85qHRqI(h\')}qJh+h sNtqKbh!h"h\'\x85qLRqM(h\')}qNh+h!sNtqObubX\t\x00\x00\x00wildcardsqPcsnakemake.io\nWildcards\nqQ)\x81qR}qS(h\x0e}qTh\x1e]qU(h h!eh h"h\'\x85qVRqW(h\')}qXh+h sNtqYbh!h"h\'\x85qZRq[(h\')}q\\h+h!sNtq]bubX\x07\x00\x00\x00threadsq^K\x01X\t\x00\x00\x00resourcesq_csnakemake.io\nResources\nq`)\x81qa(K\x01K\x01e}qb(h\x0e}qc(X\x06\x00\x00\x00_coresqdK\x00N\x86qeX\x06\x00\x00\x00_nodesqfK\x01N\x86qguh\x1e]qh(h h!eh h"h\'\x85qiRqj(h\')}qkh+h sNtqlbh!h"h\'\x85qmRqn(h\')}qoh+h!sNtqpbhdK\x01hfK\x01ubX\x03\x00\x00\x00logqqcsnakemake.io\nLog\nqr)\x81qsX.\x00\x00\x00logs/notebooks/vaccine-strain-comparison.ipynbqta}qu(h\x0e}qvX\x08\x00\x00\x00notebookqwK\x00N\x86qxsh\x1e]qy(h h!eh h"h\'\x85qzRq{(h\')}q|h+h sNtq}bh!h"h\'\x85q~Rq\x7f(h\')}q\x80h+h!sNtq\x81bhwhtubX\x06\x00\x00\x00configq\x82}q\x83(X\r\x00\x00\x00active_buildsq\x84X\x9b\x00\x00\x00simulated_sample_3 simulated_sample_3_test_tree natural_sample_1_with_90_vpm_sliding natural_sample_1_with_90_vpm_sliding_test_tree natural_sample_20191001q\x85X\x08\x00\x00\x00datasetsq\x86}q\x87(X\x12\x00\x00\x00simulated_sample_1q\x88}q\x89(X\x0b\x00\x00\x00descriptionq\x8aX^\x00\x00\x00Require a minimum fitness for randomly select amino acids in non-stationary positive selectionq\x8bX\x04\x00\x00\x00seedq\x8cK\x01X\x07\x00\x00\x00lineageq\x8dX\t\x00\x00\x00simulatedq\x8eX\x07\x00\x00\x00segmentq\x8fX\x02\x00\x00\x00haq\x90X\x11\x00\x00\x00viruses_per_monthq\x91K\nuX\x12\x00\x00\x00simulated_sample_3q\x92}q\x93(h\x8aXZ\x00\x00\x00Highest density sampling of simulated populations with same settings as simulated_sample_1q\x94h\x8cK\x03h\x8dX\t\x00\x00\x00simulatedq\x95h\x8fX\x02\x00\x00\x00haq\x96h\x91KZuX\x1c\x00\x00\x00natural_sample_1_with_10_vpmq\x97}q\x98(h\x8dX\x04\x00\x00\x00h3n2q\x99h\x8fX\x02\x00\x00\x00haq\x9aX\x0c\x00\x00\x00fauna_fieldsq\x9bXr\x00\x00\x00strain virus accession collection_date region country division location passage_category submitting_lab age genderq\x9cX\x0c\x00\x00\x00fasta_fieldsq\x9dX^\x00\x00\x00strain virus accession date region country division location passage submitting_lab age genderq\x9eX\x0f\x00\x00\x00titer_databasesq\x9fX(\x00\x00\x00tdb cdc_tdb crick_tdb vidrl_tdb niid_tdbq\xa0X\x0b\x00\x00\x00titer_assayq\xa1X\x02\x00\x00\x00hiq\xa2X\r\x00\x00\x00titer_passageq\xa3X\x04\x00\x00\x00cellq\xa4h\x91K\nX\x13\x00\x00\x00min_sequence_lengthq\xa5M\x84\x03X\x08\x00\x00\x00outliersq\xa6X\x18\x00\x00\x00config/outliers_h3n2.txtq\xa7X\x10\x00\x00\x00required_strainsq\xa8X\x1a\x00\x00\x00config/references_h3n2.txtq\xa9X\n\x00\x00\x00start_dateq\xaaX\n\x00\x00\x001994-10-01q\xabX\x08\x00\x00\x00end_dateq\xacX\n\x00\x00\x002015-10-01q\xaduX\x1c\x00\x00\x00natural_sample_0_with_90_vpmq\xae}q\xaf(h\x8dX\x04\x00\x00\x00h3n2q\xb0h\x8fX\x02\x00\x00\x00haq\xb1h\x9bXr\x00\x00\x00strain virus accession collection_date region country division location passage_category submitting_lab age genderq\xb2h\x9dX^\x00\x00\x00strain virus accession date region country division location passage submitting_lab age genderq\xb3h\x9fX(\x00\x00\x00tdb cdc_tdb crick_tdb vidrl_tdb niid_tdbq\xb4h\xa1X\x02\x00\x00\x00hiq\xb5h\xa3X\x04\x00\x00\x00cellq\xb6h\x91KZh\xa5M\x84\x03h\xa6X\x18\x00\x00\x00config/outliers_h3n2.txtq\xb7h\xa8X\x1a\x00\x00\x00config/references_h3n2.txtq\xb8h\xaaX\n\x00\x00\x001992-10-01q\xb9h\xacX\n\x00\x00\x002015-10-01q\xbauX&\x00\x00\x00natural_sample_0_with_90_vpm_test_treeq\xbb}q\xbc(h\x8dX\x04\x00\x00\x00h3n2q\xbdh\x8fX\x02\x00\x00\x00haq\xbeh\x9bXr\x00\x00\x00strain virus accession collection_date region country division location passage_category submitting_lab age genderq\xbfh\x9dX^\x00\x00\x00strain virus accession date region country division location passage submitting_lab age genderq\xc0h\x9fX(\x00\x00\x00tdb cdc_tdb crick_tdb vidrl_tdb niid_tdbq\xc1h\xa1X\x02\x00\x00\x00hiq\xc2h\xa3X\x04\x00\x00\x00cellq\xc3h\x91KZh\xa5M\x84\x03h\xa6X\x18\x00\x00\x00config/outliers_h3n2.txtq\xc4h\xa8X\x1a\x00\x00\x00config/references_h3n2.txtq\xc5h\xaaX\n\x00\x00\x001992-10-01q\xc6h\xacX\n\x00\x00\x002019-10-01q\xc7uX\x1c\x00\x00\x00natural_sample_1_with_90_vpmq\xc8}q\xc9(h\x8dX\x04\x00\x00\x00h3n2q\xcah\x8fX\x02\x00\x00\x00haq\xcbh\x9bXr\x00\x00\x00strain virus accession collection_date region country division location passage_category submitting_lab age genderq\xcch\x9dX^\x00\x00\x00strain virus accession date region country division location passage submitting_lab age genderq\xcdh\x9fX(\x00\x00\x00tdb cdc_tdb crick_tdb vidrl_tdb niid_tdbq\xceh\xa1X\x02\x00\x00\x00hiq\xcfh\xa3X\x04\x00\x00\x00cellq\xd0h\x91KZh\xa5M\x84\x03h\xa6X\x18\x00\x00\x00config/outliers_h3n2.txtq\xd1h\xa8X\x1a\x00\x00\x00config/references_h3n2.txtq\xd2X\x0e\x00\x00\x00frozen_strainsq\xd3X<\x00\x00\x00data/natural/natural_sample_1_with_90_vpm/frozen_strains.txtq\xd4h\xaaX\n\x00\x00\x001990-10-01q\xd5h\xacX\n\x00\x00\x002015-10-01q\xd6uX&\x00\x00\x00natural_sample_1_with_90_vpm_test_treeq\xd7}q\xd8(h\x8dX\x04\x00\x00\x00h3n2q\xd9h\x8fX\x02\x00\x00\x00haq\xdah\x9bXr\x00\x00\x00strain virus accession collection_date region country division location passage_category submitting_lab age genderq\xdbh\x9dX^\x00\x00\x00strain virus accession date region country division location passage submitting_lab age genderq\xdch\x9fX(\x00\x00\x00tdb cdc_tdb crick_tdb vidrl_tdb niid_tdbq\xddh\xa1X\x02\x00\x00\x00hiq\xdeh\xa3X\x04\x00\x00\x00cellq\xdfh\x91KZh\xa5M\x84\x03h\xa6X\x18\x00\x00\x00config/outliers_h3n2.txtq\xe0h\xa8X\x1a\x00\x00\x00config/references_h3n2.txtq\xe1h\xd3XF\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/frozen_strains.txtq\xe2h\xaaX\n\x00\x00\x001990-10-01q\xe3h\xacX\n\x00\x00\x002019-10-01q\xe4uX\r\x00\x00\x00luksza_lassigq\xe5}q\xe6(h\x8dX\x04\x00\x00\x00h3n2q\xe7h\x8fX\x02\x00\x00\x00haq\xe8h\x9fX(\x00\x00\x00tdb cdc_tdb crick_tdb vidrl_tdb niid_tdbq\xe9h\xa1X\x02\x00\x00\x00hiq\xeah\xa3X\x04\x00\x00\x00cellq\xebh\xa8X&\x00\x00\x00data/natural/luksza_lassig/strains.txtq\xecuuX\x06\x00\x00\x00buildsq\xed}q\xee(X\t\x00\x00\x00simulatedq\xef}q\xf0(h\x88}q\xf1(h\x8aX-\x00\x00\x00Analysis of simulated A/H3N2-like populationsq\xf2X\t\x00\x00\x00sequencesq\xf3X:\x00\x00\x00data/simulated/simulated_sample_1/filtered_sequences.fastaq\xf4X\x08\x00\x00\x00metadataq\xf5X7\x00\x00\x00data/simulated/simulated_sample_1/filtered_metadata.tsvq\xf6X\x07\x00\x00\x00strainsq\xf7X-\x00\x00\x00data/simulated/simulated_sample_1/strains.txtq\xf8h\xaaX\n\x00\x00\x002010-10-01q\xf9h\xacX\n\x00\x00\x002040-10-01q\xfaX\x0e\x00\x00\x00pivot_intervalq\xfbK\x06X\x13\x00\x00\x00min_years_per_buildq\xfcK\x06X\x19\x00\x00\x00years_back_to_build_treesq\xfdK\x06X\t\x00\x00\x00referenceq\xfeX\x1b\x00\x00\x00config/reference_h3n2_ha.gbq\xffX\n\x00\x00\x00predictorsr\x00\x01\x00\x00]r\x01\x01\x00\x00(X\x05\x00\x00\x00naiver\x02\x01\x00\x00X\x12\x00\x00\x00normalized_fitnessr\x03\x01\x00\x00X\x04\x00\x00\x00ep_xr\x04\x01\x00\x00X\x07\x00\x00\x00ne_starr\x05\x01\x00\x00X\x03\x00\x00\x00lbir\x06\x01\x00\x00X\x0f\x00\x00\x00delta_frequencyr\x07\x01\x00\x00X\x0b\x00\x00\x00lbi-ne_starr\x08\x01\x00\x00eX\x0e\x00\x00\x00best_predictorr\t\x01\x00\x00X_\x00\x00\x00results/builds/simulated/simulated_sample_1/minimal_models_by_distances/normalized_fitness.jsonr\n\x01\x00\x00uX\x1c\x00\x00\x00simulated_sample_1_full_treer\x0b\x01\x00\x00}r\x0c\x01\x00\x00(X\x0e\x00\x00\x00dataset_sampler\r\x01\x00\x00X\x12\x00\x00\x00simulated_sample_1r\x0e\x01\x00\x00h\x8aXB\x00\x00\x00Full tree for analysis of sparse simulated A/H3N2-like populationsr\x0f\x01\x00\x00h\xf3X:\x00\x00\x00data/simulated/simulated_sample_1/filtered_sequences.fastar\x10\x01\x00\x00h\xf5X7\x00\x00\x00data/simulated/simulated_sample_1/filtered_metadata.tsvr\x11\x01\x00\x00h\xf7X-\x00\x00\x00data/simulated/simulated_sample_1/strains.txtr\x12\x01\x00\x00h\xaaX\n\x00\x00\x002010-10-01r\x13\x01\x00\x00h\xacX\n\x00\x00\x002040-10-01r\x14\x01\x00\x00h\xfbK\x06h\xfcK\x1eh\xfdK\x1eh\xfeX\x1b\x00\x00\x00config/reference_h3n2_ha.gbr\x15\x01\x00\x00j\t\x01\x00\x00X_\x00\x00\x00results/builds/simulated/simulated_sample_1/minimal_models_by_distances/normalized_fitness.jsonr\x16\x01\x00\x00uX\x1c\x00\x00\x00simulated_sample_1_test_treer\x17\x01\x00\x00}r\x18\x01\x00\x00(j\r\x01\x00\x00X\x12\x00\x00\x00simulated_sample_1r\x19\x01\x00\x00h\x8aXB\x00\x00\x00Test data for analysis of sparse simulated A/H3N2-like populationsr\x1a\x01\x00\x00h\xf3X:\x00\x00\x00data/simulated/simulated_sample_1/filtered_sequences.fastar\x1b\x01\x00\x00h\xf5X7\x00\x00\x00data/simulated/simulated_sample_1/filtered_metadata.tsvr\x1c\x01\x00\x00h\xf7X-\x00\x00\x00data/simulated/simulated_sample_1/strains.txtr\x1d\x01\x00\x00h\xaaX\n\x00\x00\x002034-10-01r\x1e\x01\x00\x00h\xacX\n\x00\x00\x002050-10-01r\x1f\x01\x00\x00h\xfbK\x06h\xfcK\x06h\xfdK\x06h\xfeX\x1b\x00\x00\x00config/reference_h3n2_ha.gbr \x01\x00\x00j\t\x01\x00\x00X_\x00\x00\x00results/builds/simulated/simulated_sample_1/minimal_models_by_distances/normalized_fitness.jsonr!\x01\x00\x00uh\x92}r"\x01\x00\x00(h\x8aX<\x00\x00\x00Analysis of simulated A/H3N2-like populations (current best)r#\x01\x00\x00X\x0f\x00\x00\x00full_tree_buildr$\x01\x00\x00X\x1c\x00\x00\x00simulated_sample_3_full_treer%\x01\x00\x00h\xf3X:\x00\x00\x00data/simulated/simulated_sample_3/filtered_sequences.fastar&\x01\x00\x00h\xf5X7\x00\x00\x00data/simulated/simulated_sample_3/filtered_metadata.tsvr\'\x01\x00\x00h\xf7X-\x00\x00\x00data/simulated/simulated_sample_3/strains.txtr(\x01\x00\x00h\xaaX\n\x00\x00\x002010-10-01r)\x01\x00\x00h\xacX\n\x00\x00\x002040-10-01r*\x01\x00\x00h\xfbK\x06h\xfcK\x06h\xfdK\x06h\xfeX\x1b\x00\x00\x00config/reference_h3n2_ha.gbr+\x01\x00\x00j\x00\x01\x00\x00]r,\x01\x00\x00(X\x05\x00\x00\x00naiver-\x01\x00\x00X\x12\x00\x00\x00normalized_fitnessr.\x01\x00\x00X\x07\x00\x00\x00ep_starr/\x01\x00\x00X\x04\x00\x00\x00ep_xr0\x01\x00\x00X\x07\x00\x00\x00ne_starr1\x01\x00\x00X\x03\x00\x00\x00lbir2\x01\x00\x00X\x0f\x00\x00\x00delta_frequencyr3\x01\x00\x00X\x0f\x00\x00\x00ep_star-ne_starr4\x01\x00\x00X\x0c\x00\x00\x00ep_x-ne_starr5\x01\x00\x00X\x0b\x00\x00\x00lbi-ne_starr6\x01\x00\x00ej\t\x01\x00\x00X_\x00\x00\x00results/builds/simulated/simulated_sample_3/minimal_models_by_distances/normalized_fitness.jsonr7\x01\x00\x00X\x15\x00\x00\x00validation_predictorsr8\x01\x00\x00]r9\x01\x00\x00(X\x05\x00\x00\x00naiver:\x01\x00\x00X\x0b\x00\x00\x00lbi-ne_starr;\x01\x00\x00X\x12\x00\x00\x00normalized_fitnessr<\x01\x00\x00euX\x1c\x00\x00\x00simulated_sample_3_full_treer=\x01\x00\x00}r>\x01\x00\x00(j\r\x01\x00\x00X\x12\x00\x00\x00simulated_sample_3r?\x01\x00\x00h\x8aXA\x00\x00\x00Full tree for analysis of dense simulated A/H3N2-like populationsr@\x01\x00\x00h\xf3X:\x00\x00\x00data/simulated/simulated_sample_3/filtered_sequences.fastarA\x01\x00\x00h\xf5X7\x00\x00\x00data/simulated/simulated_sample_3/filtered_metadata.tsvrB\x01\x00\x00h\xf7X-\x00\x00\x00data/simulated/simulated_sample_3/strains.txtrC\x01\x00\x00h\xaaX\n\x00\x00\x002030-10-01rD\x01\x00\x00h\xacX\n\x00\x00\x002040-10-01rE\x01\x00\x00h\xfbK\x06h\xfcK\nh\xfdK\nh\xfeX\x1b\x00\x00\x00config/reference_h3n2_ha.gbrF\x01\x00\x00j\t\x01\x00\x00X_\x00\x00\x00results/builds/simulated/simulated_sample_3/minimal_models_by_distances/normalized_fitness.jsonrG\x01\x00\x00uX\x1c\x00\x00\x00simulated_sample_3_test_treerH\x01\x00\x00}rI\x01\x00\x00(j\r\x01\x00\x00X\x12\x00\x00\x00simulated_sample_3rJ\x01\x00\x00X\x10\x00\x00\x00validation_buildrK\x01\x00\x00X\x12\x00\x00\x00simulated_sample_3rL\x01\x00\x00j$\x01\x00\x00X!\x00\x00\x00simulated_sample_3_full_test_treerM\x01\x00\x00h\x8aXA\x00\x00\x00Test data for analysis of dense simulated A/H3N2-like populationsrN\x01\x00\x00h\xf3X:\x00\x00\x00data/simulated/simulated_sample_3/filtered_sequences.fastarO\x01\x00\x00h\xf5X7\x00\x00\x00data/simulated/simulated_sample_3/filtered_metadata.tsvrP\x01\x00\x00h\xf7X-\x00\x00\x00data/simulated/simulated_sample_3/strains.txtrQ\x01\x00\x00h\xaaX\n\x00\x00\x002034-04-01rR\x01\x00\x00h\xacX\n\x00\x00\x002049-10-01rS\x01\x00\x00h\xfbK\x06h\xfcK\x06h\xfdK\x06h\xfeX\x1b\x00\x00\x00config/reference_h3n2_ha.gbrT\x01\x00\x00j\x00\x01\x00\x00]rU\x01\x00\x00(X\x05\x00\x00\x00naiverV\x01\x00\x00X\x12\x00\x00\x00normalized_fitnessrW\x01\x00\x00X\x07\x00\x00\x00ep_starrX\x01\x00\x00X\x04\x00\x00\x00ep_xrY\x01\x00\x00X\x07\x00\x00\x00ne_starrZ\x01\x00\x00X\x03\x00\x00\x00lbir[\x01\x00\x00X\x0f\x00\x00\x00delta_frequencyr\\\x01\x00\x00X\x0f\x00\x00\x00ep_star-ne_starr]\x01\x00\x00X\x0c\x00\x00\x00ep_x-ne_starr^\x01\x00\x00X\x0b\x00\x00\x00lbi-ne_starr_\x01\x00\x00ej\t\x01\x00\x00X_\x00\x00\x00results/builds/simulated/simulated_sample_3/minimal_models_by_distances/normalized_fitness.jsonr`\x01\x00\x00j8\x01\x00\x00]ra\x01\x00\x00(X\x05\x00\x00\x00naiverb\x01\x00\x00X\x0b\x00\x00\x00lbi-ne_starrc\x01\x00\x00X\x12\x00\x00\x00normalized_fitnessrd\x01\x00\x00euX!\x00\x00\x00simulated_sample_3_full_test_treere\x01\x00\x00}rf\x01\x00\x00(j\r\x01\x00\x00X\x12\x00\x00\x00simulated_sample_3rg\x01\x00\x00h\x8aXO\x00\x00\x00Full tree for test data for analysis of dense simulated A/H3N2-like populationsrh\x01\x00\x00h\xf3X:\x00\x00\x00data/simulated/simulated_sample_3/filtered_sequences.fastari\x01\x00\x00h\xf5X7\x00\x00\x00data/simulated/simulated_sample_3/filtered_metadata.tsvrj\x01\x00\x00h\xf7X-\x00\x00\x00data/simulated/simulated_sample_3/strains.txtrk\x01\x00\x00h\xaaX\n\x00\x00\x002039-10-01rl\x01\x00\x00h\xacX\n\x00\x00\x002049-10-01rm\x01\x00\x00h\xfbK\x06h\xfcK\nh\xfdK\nh\xfeX\x1b\x00\x00\x00config/reference_h3n2_ha.gbrn\x01\x00\x00j\t\x01\x00\x00X_\x00\x00\x00results/builds/simulated/simulated_sample_3/minimal_models_by_distances/normalized_fitness.jsonro\x01\x00\x00uuX\x07\x00\x00\x00naturalrp\x01\x00\x00}rq\x01\x00\x00(h\xe5}rr\x01\x00\x00(h\x8aXF\x00\x00\x00Manually curated build including sequences from Luksza and Lassig 2014rs\x01\x00\x00h\xf3X1\x00\x00\x00data/natural/luksza_lassig/sequences_luksza.fastart\x01\x00\x00h\xf5X.\x00\x00\x00data/natural/luksza_lassig/metadata_luksza.tsvru\x01\x00\x00X\x06\x00\x00\x00titersrv\x01\x00\x00X%\x00\x00\x00data/natural/luksza_lassig/titers.tsvrw\x01\x00\x00h\xaaX\n\x00\x00\x001991-10-01rx\x01\x00\x00h\xacX\n\x00\x00\x002012-10-01ry\x01\x00\x00h\xfbK\x06h\xfcK\x01h\xfdK2h\xfeX.\x00\x00\x00data/natural/luksza_lassig/A_Albany_17_1968.gbrz\x01\x00\x00X\x0f\x00\x00\x00training_windowr{\x01\x00\x00K\x08j\x00\x01\x00\x00]r|\x01\x00\x00(X\x05\x00\x00\x00naiver}\x01\x00\x00X\x04\x00\x00\x00ep_xr~\x01\x00\x00X\x07\x00\x00\x00ne_starr\x7f\x01\x00\x00X\x03\x00\x00\x00lbir\x80\x01\x00\x00X\x0c\x00\x00\x00ep_x-ne_starr\x81\x01\x00\x00X\x10\x00\x00\x00lbi-ep_x-ne_starr\x82\x01\x00\x00euX$\x00\x00\x00natural_sample_1_with_10_vpm_slidingr\x83\x01\x00\x00}r\x84\x01\x00\x00(j\r\x01\x00\x00X\x1c\x00\x00\x00natural_sample_1_with_10_vpmr\x85\x01\x00\x00h\x8aXZ\x00\x00\x00A build with the same data as the natural sample 1 but with trees built in sliding windowsr\x86\x01\x00\x00h\xf3XB\x00\x00\x00data/natural/natural_sample_1_with_10_vpm/filtered_sequences.fastar\x87\x01\x00\x00h\xf5X>\x00\x00\x00data/natural/natural_sample_1_with_10_vpm/strains_metadata.tsvr\x88\x01\x00\x00X\x11\x00\x00\x00complete_metadatar\x89\x01\x00\x00X?\x00\x00\x00data/natural/natural_sample_1_with_10_vpm/filtered_metadata.tsvr\x8a\x01\x00\x00jv\x01\x00\x00X4\x00\x00\x00data/natural/natural_sample_1_with_10_vpm/titers.tsvr\x8b\x01\x00\x00h\xaaX\n\x00\x00\x001994-10-01r\x8c\x01\x00\x00h\xacX\n\x00\x00\x002015-10-01r\x8d\x01\x00\x00h\xfbK\x06h\xfcK\x01h\xfdK\x06h\xfeX\x1b\x00\x00\x00config/reference_h3n2_ha.gbr\x8e\x01\x00\x00j\x00\x01\x00\x00]r\x8f\x01\x00\x00(X\x05\x00\x00\x00naiver\x90\x01\x00\x00X\x04\x00\x00\x00ep_xr\x91\x01\x00\x00X\x06\x00\x00\x00cTiterr\x92\x01\x00\x00X\t\x00\x00\x00cTiterSubr\x93\x01\x00\x00X\x0b\x00\x00\x00cTiterSub_xr\x94\x01\x00\x00X\x07\x00\x00\x00ne_starr\x95\x01\x00\x00X\x08\x00\x00\x00dms_starr\x96\x01\x00\x00X\x03\x00\x00\x00lbir\x97\x01\x00\x00X\x0f\x00\x00\x00delta_frequencyr\x98\x01\x00\x00euX$\x00\x00\x00natural_sample_0_with_90_vpm_slidingr\x99\x01\x00\x00}r\x9a\x01\x00\x00(h\x8aX>\x00\x00\x00Very dense sampling of viruses over 23 years of H3N2 evolutionr\x9b\x01\x00\x00j\r\x01\x00\x00X\x1c\x00\x00\x00natural_sample_0_with_90_vpmr\x9c\x01\x00\x00h\xf3XB\x00\x00\x00data/natural/natural_sample_0_with_90_vpm/filtered_sequences.fastar\x9d\x01\x00\x00h\xf5X>\x00\x00\x00data/natural/natural_sample_0_with_90_vpm/strains_metadata.tsvr\x9e\x01\x00\x00jv\x01\x00\x00X4\x00\x00\x00data/natural/natural_sample_0_with_90_vpm/titers.tsvr\x9f\x01\x00\x00h\xaaX\n\x00\x00\x001992-10-01r\xa0\x01\x00\x00h\xacX\n\x00\x00\x002015-10-01r\xa1\x01\x00\x00h\xfbK\x06h\xfcK\x06h\xfdK\x06h\xfeX\x1b\x00\x00\x00config/reference_h3n2_ha.gbr\xa2\x01\x00\x00X\x0e\x00\x00\x00all_predictorsr\xa3\x01\x00\x00]r\xa4\x01\x00\x00(X\x05\x00\x00\x00naiver\xa5\x01\x00\x00X\x02\x00\x00\x00epr\xa6\x01\x00\x00X\x07\x00\x00\x00ep_wolfr\xa7\x01\x00\x00X\x04\x00\x00\x00ep_xr\xa8\x01\x00\x00X\x02\x00\x00\x00rbr\xa9\x01\x00\x00X\x06\x00\x00\x00cTiterr\xaa\x01\x00\x00X\x08\x00\x00\x00cTiter_xr\xab\x01\x00\x00X\t\x00\x00\x00cTiterSubr\xac\x01\x00\x00X\x0b\x00\x00\x00cTiterSub_xr\xad\x01\x00\x00X\x07\x00\x00\x00ne_starr\xae\x01\x00\x00X\x08\x00\x00\x00dms_starr\xaf\x01\x00\x00X\x0e\x00\x00\x00dms_nonepitoper\xb0\x01\x00\x00X\x0b\x00\x00\x00dms_entropyr\xb1\x01\x00\x00X\x03\x00\x00\x00lbir\xb2\x01\x00\x00X\x0f\x00\x00\x00delta_frequencyr\xb3\x01\x00\x00X\x0c\x00\x00\x00ep_x-ne_starr\xb4\x01\x00\x00X\x0b\x00\x00\x00ne_star-lbir\xb5\x01\x00\x00X\x10\x00\x00\x00cTiter_x-ne_starr\xb6\x01\x00\x00X\x14\x00\x00\x00cTiter_x-ne_star-lbir\xb7\x01\x00\x00ej\x00\x01\x00\x00]r\xb8\x01\x00\x00(X\x05\x00\x00\x00naiver\xb9\x01\x00\x00X\x04\x00\x00\x00ep_xr\xba\x01\x00\x00X\x08\x00\x00\x00cTiter_xr\xbb\x01\x00\x00X\x07\x00\x00\x00ne_starr\xbc\x01\x00\x00X\x08\x00\x00\x00dms_starr\xbd\x01\x00\x00X\x03\x00\x00\x00lbir\xbe\x01\x00\x00X\x0f\x00\x00\x00delta_frequencyr\xbf\x01\x00\x00ej\t\x01\x00\x00X`\x00\x00\x00results/builds/natural/natural_sample_0_with_90_vpm_sliding/models_by_distances/ne_star-lbi.jsonr\xc0\x01\x00\x00uh\xbb}r\xc1\x01\x00\x00(h\x8aX:\x00\x00\x00Test data for analysis of dense natural A/H3N2 populationsr\xc2\x01\x00\x00h\xf3XL\x00\x00\x00data/natural/natural_sample_0_with_90_vpm_test_tree/filtered_sequences.fastar\xc3\x01\x00\x00h\xf5XH\x00\x00\x00data/natural/natural_sample_0_with_90_vpm_test_tree/strains_metadata.tsvr\xc4\x01\x00\x00jv\x01\x00\x00X>\x00\x00\x00data/natural/natural_sample_0_with_90_vpm_test_tree/titers.tsvr\xc5\x01\x00\x00h\xaaX\n\x00\x00\x002009-10-01r\xc6\x01\x00\x00h\xacX\n\x00\x00\x002019-04-01r\xc7\x01\x00\x00h\xfbK\x06h\xfcK\x06h\xfdK\x06h\xfeX\x1b\x00\x00\x00config/reference_h3n2_ha.gbr\xc8\x01\x00\x00j\t\x01\x00\x00X`\x00\x00\x00results/builds/natural/natural_sample_0_with_90_vpm_sliding/models_by_distances/ne_star-lbi.jsonr\xc9\x01\x00\x00uX.\x00\x00\x00natural_sample_0_with_90_vpm_sliding_full_treer\xca\x01\x00\x00}r\xcb\x01\x00\x00(h\x8aXU\x00\x00\x00Full tree for validation of dense sampling of viruses over 23 years of H3N2 evolutionr\xcc\x01\x00\x00j\r\x01\x00\x00X\x1c\x00\x00\x00natural_sample_0_with_90_vpmr\xcd\x01\x00\x00h\xf3XB\x00\x00\x00data/natural/natural_sample_0_with_90_vpm/filtered_sequences.fastar\xce\x01\x00\x00h\xf5X>\x00\x00\x00data/natural/natural_sample_0_with_90_vpm/strains_metadata.tsvr\xcf\x01\x00\x00jv\x01\x00\x00X4\x00\x00\x00data/natural/natural_sample_0_with_90_vpm/titers.tsvr\xd0\x01\x00\x00h\xaaX\n\x00\x00\x001992-10-01r\xd1\x01\x00\x00h\xacX\n\x00\x00\x002015-10-01r\xd2\x01\x00\x00h\xfbK\x06h\xfcK\x17h\xfdK\x1eh\xfeX\x1b\x00\x00\x00config/reference_h3n2_ha.gbr\xd3\x01\x00\x00j\x00\x01\x00\x00]r\xd4\x01\x00\x00X\x0b\x00\x00\x00ne_star-lbir\xd5\x01\x00\x00aj\t\x01\x00\x00X`\x00\x00\x00results/builds/natural/natural_sample_0_with_90_vpm_sliding/models_by_distances/ne_star-lbi.jsonr\xd6\x01\x00\x00uX$\x00\x00\x00natural_sample_1_with_90_vpm_slidingr\xd7\x01\x00\x00}r\xd8\x01\x00\x00(h\x8aX\x82\x00\x00\x00Very dense sampling of viruses over 25 years of H3N2 evolution after filtering outliers that don\'t match clock rate (current best)r\xd9\x01\x00\x00j\r\x01\x00\x00X\x1c\x00\x00\x00natural_sample_1_with_90_vpmr\xda\x01\x00\x00j$\x01\x00\x00X.\x00\x00\x00natural_sample_1_with_90_vpm_sliding_full_treer\xdb\x01\x00\x00h\xf3XB\x00\x00\x00data/natural/natural_sample_1_with_90_vpm/filtered_sequences.fastar\xdc\x01\x00\x00h\xf5X>\x00\x00\x00data/natural/natural_sample_1_with_90_vpm/strains_metadata.tsvr\xdd\x01\x00\x00jv\x01\x00\x00X4\x00\x00\x00data/natural/natural_sample_1_with_90_vpm/titers.tsvr\xde\x01\x00\x00h\xaaX\n\x00\x00\x001990-10-01r\xdf\x01\x00\x00h\xacX\n\x00\x00\x002015-10-01r\xe0\x01\x00\x00h\xfbK\x06h\xfcK\x06h\xfdK\x06h\xfeX\x1b\x00\x00\x00config/reference_h3n2_ha.gbr\xe1\x01\x00\x00j\x00\x01\x00\x00]r\xe2\x01\x00\x00(X\x05\x00\x00\x00naiver\xe3\x01\x00\x00X\x07\x00\x00\x00ep_starr\xe4\x01\x00\x00X\t\x00\x00\x00ep_x_koelr\xe5\x01\x00\x00X\t\x00\x00\x00ep_x_wolfr\xe6\x01\x00\x00X\x04\x00\x00\x00ep_xr\xe7\x01\x00\x00X\x08\x00\x00\x00oracle_xr\xe8\x01\x00\x00X\x06\x00\x00\x00cTiterr\xe9\x01\x00\x00X\x08\x00\x00\x00cTiter_xr\xea\x01\x00\x00X\x07\x00\x00\x00ne_starr\xeb\x01\x00\x00X\x08\x00\x00\x00dms_starr\xec\x01\x00\x00X\x0e\x00\x00\x00dms_nonepitoper\xed\x01\x00\x00X\x0b\x00\x00\x00dms_entropyr\xee\x01\x00\x00X\x03\x00\x00\x00lbir\xef\x01\x00\x00X\x0f\x00\x00\x00delta_frequencyr\xf0\x01\x00\x00X\x0f\x00\x00\x00ep_star-ne_starr\xf1\x01\x00\x00X\x0c\x00\x00\x00ep_x-ne_starr\xf2\x01\x00\x00X\x0b\x00\x00\x00ne_star-lbir\xf3\x01\x00\x00X\x10\x00\x00\x00cTiter_x-ne_starr\xf4\x01\x00\x00X\x14\x00\x00\x00cTiter_x-ne_star-lbir\xf5\x01\x00\x00ej\t\x01\x00\x00Xh\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding/minimal_models_by_distances/ne_star-lbi.jsonr\xf6\x01\x00\x00j8\x01\x00\x00]r\xf7\x01\x00\x00(X\x05\x00\x00\x00naiver\xf8\x01\x00\x00X\x0b\x00\x00\x00ne_star-lbir\xf9\x01\x00\x00X\x10\x00\x00\x00cTiter_x-ne_starr\xfa\x01\x00\x00euX.\x00\x00\x00natural_sample_1_with_90_vpm_sliding_full_treer\xfb\x01\x00\x00}r\xfc\x01\x00\x00(h\x8aX\x81\x00\x00\x00Full tree for very dense sampling of viruses over 25 years of H3N2 evolution after filtering outliers that don\'t match clock rater\xfd\x01\x00\x00j\r\x01\x00\x00X\x1c\x00\x00\x00natural_sample_1_with_90_vpmr\xfe\x01\x00\x00h\xf3XB\x00\x00\x00data/natural/natural_sample_1_with_90_vpm/filtered_sequences.fastar\xff\x01\x00\x00h\xf5X>\x00\x00\x00data/natural/natural_sample_1_with_90_vpm/strains_metadata.tsvr\x00\x02\x00\x00jv\x01\x00\x00X4\x00\x00\x00data/natural/natural_sample_1_with_90_vpm/titers.tsvr\x01\x02\x00\x00h\xaaX\n\x00\x00\x001990-10-01r\x02\x02\x00\x00h\xacX\n\x00\x00\x002015-10-01r\x03\x02\x00\x00h\xfbK\x06h\xfcK\x19h\xfdK\x1eh\xfeX\x1b\x00\x00\x00config/reference_h3n2_ha.gbr\x04\x02\x00\x00j\x00\x01\x00\x00]r\x05\x02\x00\x00X\x0b\x00\x00\x00ne_star-lbir\x06\x02\x00\x00aj\t\x01\x00\x00Xh\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding/minimal_models_by_distances/ne_star-lbi.jsonr\x07\x02\x00\x00uX.\x00\x00\x00natural_sample_1_with_90_vpm_sliding_test_treer\x08\x02\x00\x00}r\t\x02\x00\x00(h\x8aX\x81\x00\x00\x00Test data for very dense sampling of viruses over 25 years of H3N2 evolution after filtering outliers that don\'t match clock rater\n\x02\x00\x00j\r\x01\x00\x00X&\x00\x00\x00natural_sample_1_with_90_vpm_test_treer\x0b\x02\x00\x00jK\x01\x00\x00X$\x00\x00\x00natural_sample_1_with_90_vpm_slidingr\x0c\x02\x00\x00j$\x01\x00\x00X3\x00\x00\x00natural_sample_1_with_90_vpm_sliding_full_test_treer\r\x02\x00\x00h\xf3XL\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/filtered_sequences.fastar\x0e\x02\x00\x00h\xf5XH\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/strains_metadata.tsvr\x0f\x02\x00\x00jv\x01\x00\x00X>\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/titers.tsvr\x10\x02\x00\x00h\xaaX\n\x00\x00\x002009-04-01r\x11\x02\x00\x00h\xacX\n\x00\x00\x002019-10-01r\x12\x02\x00\x00h\xfbK\x06h\xfcK\x06h\xfdK\x06h\xfeX\x1b\x00\x00\x00config/reference_h3n2_ha.gbr\x13\x02\x00\x00j\x00\x01\x00\x00]r\x14\x02\x00\x00(X\x05\x00\x00\x00naiver\x15\x02\x00\x00X\x07\x00\x00\x00ep_starr\x16\x02\x00\x00X\t\x00\x00\x00ep_x_koelr\x17\x02\x00\x00X\t\x00\x00\x00ep_x_wolfr\x18\x02\x00\x00X\x04\x00\x00\x00ep_xr\x19\x02\x00\x00X\x08\x00\x00\x00oracle_xr\x1a\x02\x00\x00X\x06\x00\x00\x00cTiterr\x1b\x02\x00\x00X\x08\x00\x00\x00cTiter_xr\x1c\x02\x00\x00X\x07\x00\x00\x00ne_starr\x1d\x02\x00\x00X\x08\x00\x00\x00dms_starr\x1e\x02\x00\x00X\x0e\x00\x00\x00dms_nonepitoper\x1f\x02\x00\x00X\x0b\x00\x00\x00dms_entropyr \x02\x00\x00X\x03\x00\x00\x00lbir!\x02\x00\x00X\x0f\x00\x00\x00delta_frequencyr"\x02\x00\x00X\x0f\x00\x00\x00ep_star-ne_starr#\x02\x00\x00X\x0c\x00\x00\x00ep_x-ne_starr$\x02\x00\x00X\x0b\x00\x00\x00ne_star-lbir%\x02\x00\x00X\x10\x00\x00\x00cTiter_x-ne_starr&\x02\x00\x00X\x14\x00\x00\x00cTiter_x-ne_star-lbir\'\x02\x00\x00ej\t\x01\x00\x00Xm\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding/minimal_models_by_distances/cTiter_x-ne_star.jsonr(\x02\x00\x00j8\x01\x00\x00]r)\x02\x00\x00(X\x05\x00\x00\x00naiver*\x02\x00\x00X\x0b\x00\x00\x00ne_star-lbir+\x02\x00\x00X\x10\x00\x00\x00cTiter_x-ne_starr,\x02\x00\x00euX3\x00\x00\x00natural_sample_1_with_90_vpm_sliding_full_test_treer-\x02\x00\x00}r.\x02\x00\x00(h\x8aX\x8f\x00\x00\x00Full tree for test data for very dense sampling of viruses over 25 years of H3N2 evolution after filtering outliers that don\'t match clock rater/\x02\x00\x00j\r\x01\x00\x00X&\x00\x00\x00natural_sample_1_with_90_vpm_test_treer0\x02\x00\x00h\xf3XL\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/filtered_sequences.fastar1\x02\x00\x00h\xf5XH\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/strains_metadata.tsvr2\x02\x00\x00jv\x01\x00\x00X>\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/titers.tsvr3\x02\x00\x00h\xaaX\n\x00\x00\x002009-10-01r4\x02\x00\x00h\xacX\n\x00\x00\x002019-10-01r5\x02\x00\x00h\xfbK\x06h\xfcK\nh\xfdK\nh\xfeX\x1b\x00\x00\x00config/reference_h3n2_ha.gbr6\x02\x00\x00j\x00\x01\x00\x00]r7\x02\x00\x00X\x0b\x00\x00\x00ne_star-lbir8\x02\x00\x00aj\t\x01\x00\x00Xm\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding/minimal_models_by_distances/cTiter_x-ne_star.jsonr9\x02\x00\x00uX\x17\x00\x00\x00natural_sample_20191001r:\x02\x00\x00}r;\x02\x00\x00(h\x8aX\x83\x00\x00\x00Most recent build with very dense sampling of viruses to evaluate change in model coefficients during timepoints in the test periodr<\x02\x00\x00j\r\x01\x00\x00X&\x00\x00\x00natural_sample_1_with_90_vpm_test_treer=\x02\x00\x00h\xf3XL\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/filtered_sequences.fastar>\x02\x00\x00h\xf5XH\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/strains_metadata.tsvr?\x02\x00\x00jv\x01\x00\x00X>\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/titers.tsvr@\x02\x00\x00X\n\x00\x00\x00fra_titersrA\x02\x00\x00XB\x00\x00\x00data/natural/natural_sample_1_with_90_vpm_test_tree/fra_titers.tsvrB\x02\x00\x00h\xaaX\n\x00\x00\x002002-04-01rC\x02\x00\x00h\xacX\n\x00\x00\x002019-10-01rD\x02\x00\x00h\xfbK\x06h\xfcK\x06h\xfdK\x06h\xfeX\x1b\x00\x00\x00config/reference_h3n2_ha.gbrE\x02\x00\x00j\x00\x01\x00\x00]rF\x02\x00\x00(X\x05\x00\x00\x00naiverG\x02\x00\x00X\x14\x00\x00\x00fra_cTiter_x-ne_starrH\x02\x00\x00X\x0b\x00\x00\x00ne_star-lbirI\x02\x00\x00X\x10\x00\x00\x00cTiter_x-ne_starrJ\x02\x00\x00X\x14\x00\x00\x00cTiter_x-ne_star-lbirK\x02\x00\x00ej\t\x01\x00\x00Xm\x00\x00\x00results/builds/natural/natural_sample_1_with_90_vpm_sliding/minimal_models_by_distances/cTiter_x-ne_star.jsonrL\x02\x00\x00uuuX\r\x00\x00\x00path_to_faunarM\x02\x00\x00X\x08\x00\x00\x00../faunarN\x02\x00\x00X\x1a\x00\x00\x00years_for_titer_alignmentsrO\x02\x00\x00K\nX\x12\x00\x00\x00min_tips_per_claderP\x02\x00\x00K\x01X\x17\x00\x00\x00min_frequency_per_claderQ\x02\x00\x00G\x00\x00\x00\x00\x00\x00\x00\x00X\x0c\x00\x00\x00delta_pivotsrR\x02\x00\x00K\x01X\x1a\x00\x00\x00months_for_distance_seasonrS\x02\x00\x00K\x0cX\x1f\x00\x00\x00months_back_for_current_samplesrT\x02\x00\x00K\x06X\x17\x00\x00\x00max_years_for_distancesrU\x02\x00\x00K\x05X\x1e\x00\x00\x00years_back_for_target_distancerV\x02\x00\x00K\x03X\x19\x00\x00\x00target_distance_attributerW\x02\x00\x00X\x07\x00\x00\x00hammingrX\x02\x00\x00jv\x01\x00\x00}rY\x02\x00\x00(X\x08\x00\x00\x00passagesrZ\x02\x00\x00]r[\x02\x00\x00X\x04\x00\x00\x00cellr\\\x02\x00\x00aX\x06\x00\x00\x00assaysr]\x02\x00\x00]r^\x02\x00\x00X\x02\x00\x00\x00hir_\x02\x00\x00auj\x00\x01\x00\x00]r`\x02\x00\x00(X\x05\x00\x00\x00naivera\x02\x00\x00X\x03\x00\x00\x00lbirb\x02\x00\x00X\x02\x00\x00\x00eprc\x02\x00\x00X\x07\x00\x00\x00ep_starrd\x02\x00\x00X\x04\x00\x00\x00ep_xre\x02\x00\x00X\x06\x00\x00\x00cTiterrf\x02\x00\x00X\t\x00\x00\x00cTiterSubrg\x02\x00\x00X\x0e\x00\x00\x00cTiterSub_starrh\x02\x00\x00X\x0b\x00\x00\x00cTiterSub_xri\x02\x00\x00X\x0f\x00\x00\x00delta_frequencyrj\x02\x00\x00X\x08\x00\x00\x00dms_starrk\x02\x00\x00X\x07\x00\x00\x00ne_starrl\x02\x00\x00X\x13\x00\x00\x00lbi-delta_frequencyrm\x02\x00\x00X\x0b\x00\x00\x00lbi-ne_starrn\x02\x00\x00X\x12\x00\x00\x00lbi-cTiter-ne_starro\x02\x00\x00X\x10\x00\x00\x00lbi-ep_x-ne_starrp\x02\x00\x00eX\x14\x00\x00\x00predictors_simulatedrq\x02\x00\x00]rr\x02\x00\x00(X\x05\x00\x00\x00naivers\x02\x00\x00X\x07\x00\x00\x00fitnessrt\x02\x00\x00X\x03\x00\x00\x00lbiru\x02\x00\x00X\x04\x00\x00\x00ep_xrv\x02\x00\x00X\x0f\x00\x00\x00delta_frequencyrw\x02\x00\x00X\x07\x00\x00\x00ne_starrx\x02\x00\x00X\x0c\x00\x00\x00ep_x-ne_starry\x02\x00\x00X\x0b\x00\x00\x00lbi-ne_starrz\x02\x00\x00X\x10\x00\x00\x00lbi-ep_x-ne_starr{\x02\x00\x00eX\x0b\x00\x00\x00frequenciesr|\x02\x00\x00}r}\x02\x00\x00(X\x10\x00\x00\x00narrow_bandwidthr~\x02\x00\x00G?\xc5Vl\xf4\x1f!-X\x0e\x00\x00\x00wide_bandwidthr\x7f\x02\x00\x00G?\xd0\x00\x00\x00\x00\x00\x00X\x0f\x00\x00\x00proportion_wider\x80\x02\x00\x00G\x00\x00\x00\x00\x00\x00\x00\x00X\x0f\x00\x00\x00pivot_frequencyr\x81\x02\x00\x00K\x06X\n\x00\x00\x00bandwidthsr\x82\x02\x00\x00]r\x83\x02\x00\x00(G?\x94z\xe1G\xae\x14{G?\xa4z\xe1G\xae\x14{G?\xb4z\xe1G\xae\x14{G?\xc4z\xe1G\xae\x14{G?\xd0\x00\x00\x00\x00\x00\x00G?\xd5\x1e\xb8Q\xeb\x85\x1fG?\xe0\x00\x00\x00\x00\x00\x00eX\x16\x00\x00\x00min_mutation_frequencyr\x84\x02\x00\x00G\x00\x00\x00\x00\x00\x00\x00\x00X\t\x00\x00\x00stiffnessr\x85\x02\x00\x00K\x14X\x07\x00\x00\x00inertiar\x86\x02\x00\x00G?\xc9\x99\x99\x99\x99\x99\x9aX\x08\x00\x00\x00min_freqr\x87\x02\x00\x00G?\x84z\xe1G\xae\x14{X\x10\x00\x00\x00preferred_methodr\x88\x02\x00\x00X\x03\x00\x00\x00kder\x89\x02\x00\x00X\x17\x00\x00\x00max_years_for_diffusionr\x8a\x02\x00\x00K\x02uX\x03\x00\x00\x00lbir\x8b\x02\x00\x00}r\x8c\x02\x00\x00(X\x03\x00\x00\x00taur\x8d\x02\x00\x00G?\xd3333333X\x06\x00\x00\x00windowr\x8e\x02\x00\x00G?\xe0\x00\x00\x00\x00\x00\x00uX\x19\x00\x00\x00excluded_node_data_fieldsr\x8f\x02\x00\x00]r\x90\x02\x00\x00(X\x07\x00\x00\x00aa_mutsr\x91\x02\x00\x00X\x0c\x00\x00\x00aa_sequencesr\x92\x02\x00\x00X\x12\x00\x00\x00country_confidencer\x93\x02\x00\x00X\x0b\x00\x00\x00ep_pairwiser\x94\x02\x00\x00X\x12\x00\x00\x00cTiterSub_pairwiser\x95\x02\x00\x00X\x12\x00\x00\x00ep_luksza_pairwiser\x96\x02\x00\x00X\x13\x00\x00\x00ep_kratsch_pairwiser\x97\x02\x00\x00X\x04\x00\x00\x00mutsr\x98\x02\x00\x00X\x13\x00\x00\x00num_date_confidencer\x99\x02\x00\x00X\x11\x00\x00\x00region_confidencer\x9a\x02\x00\x00eX\x0e\x00\x00\x00cross_immunityr\x9b\x02\x00\x00}r\x9c\x02\x00\x00X\x04\x00\x00\x00h3n2r\x9d\x02\x00\x00}r\x9e\x02\x00\x00X\x02\x00\x00\x00har\x9f\x02\x00\x00}r\xa0\x02\x00\x00(h\xef}r\xa1\x02\x00\x00(X\x13\x00\x00\x00distance_attributesr\xa2\x02\x00\x00X\x0b\x00\x00\x00ep_pairwiser\xa3\x02\x00\x00X\x13\x00\x00\x00immunity_attributesr\xa4\x02\x00\x00X\x04\x00\x00\x00ep_xr\xa5\x02\x00\x00X\r\x00\x00\x00decay_factorsr\xa6\x02\x00\x00X\x04\x00\x00\x0014.0r\xa7\x02\x00\x00ujp\x01\x00\x00}r\xa8\x02\x00\x00(j\xa2\x02\x00\x00X=\x00\x00\x00ep_pairwise ep_pairwise_wolf ep_pairwise_koel oracle_pairwiser\xa9\x02\x00\x00j\xa4\x02\x00\x00X!\x00\x00\x00ep_x ep_x_wolf ep_x_koel oracle_xr\xaa\x02\x00\x00j\xa6\x02\x00\x00X\x13\x00\x00\x0014.0 14.0 14.0 14.0r\xab\x02\x00\x00uussX\r\x00\x00\x00fitness_modelr\xac\x02\x00\x00}r\xad\x02\x00\x00(j\x87\x02\x00\x00G?\x84z\xe1G\xae\x14{X\x08\x00\x00\x00max_freqr\xae\x02\x00\x00G?\xef\xae\x14z\xe1G\xaej{\x01\x00\x00K\x06X\x13\x00\x00\x00delta_months_to_fitr\xaf\x02\x00\x00K\x0cX\x0c\x00\x00\x00delta_monthsr\xb0\x02\x00\x00]r\xb1\x02\x00\x00(K\x06K\x0ceX\x0f\x00\x00\x00primary_segmentr\xb2\x02\x00\x00X\x02\x00\x00\x00har\xb3\x02\x00\x00X\x13\x00\x00\x00clade_cost_functionr\xb4\x02\x00\x00X\x10\x00\x00\x00information_gainr\xb5\x02\x00\x00X\x16\x00\x00\x00distance_cost_functionr\xb6\x02\x00\x00X\x07\x00\x00\x00diffsumr\xb7\x02\x00\x00X\t\x00\x00\x00l1_lambdar\xb8\x02\x00\x00G?\xb9\x99\x99\x99\x99\x99\x9aX\x0b\x00\x00\x00pseudocountr\xb9\x02\x00\x00G?PbM\xd2\xf1\xa9\xfcuuX\x04\x00\x00\x00ruler\xba\x02\x00\x00X\x1d\x00\x00\x00figure_for_vaccine_comparisonr\xbb\x02\x00\x00X\x0f\x00\x00\x00bench_iterationr\xbc\x02\x00\x00NX\t\x00\x00\x00scriptdirr\xbd\x02\x00\x00X7\x00\x00\x00/Users/jlhudd/projects/docker/flu-forecasting/notebooksr\xbe\x02\x00\x00ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir('/Users/jlhudd/projects/docker/flu-forecasting');
######## snakemake preamble end #########

# %% [markdown]
# # Figure 8. Compare vaccine strains to estimated and observed closest strains to the future
#
# Observed distance to natural H3N2 populations one year into the future for each vaccine strain (green) and the observed (blue) and estimated (orange) closest strains to the future at the corresponding timepoints. Vaccine strains were assigned to the validation or test timepoint closest to the date they were selected by the WHO. The distance to the future of each vaccine strain was calculated from their amino acid sequences and the frequencies and sequences of the corresponding population one year in the future. The estimated closest strain to the future was identified by either the best model in the validation period (mutational load and LBI) or the best model in the test period
# (HI antigenic novelty and mutational load).

# %%
validation_tip_attributes_path = snakemake.input.validation_tip_attributes
test_tip_attributes_path = snakemake.input.test_tip_attributes

cTiter_x_ne_star_validation_forecasts_path = snakemake.input.cTiter_x_ne_star_validation_forecasts_path
ne_star_lbi_validation_forecasts_path = snakemake.input.ne_star_lbi_validation_forecasts_path

cTiter_x_ne_star_test_forecasts_path = snakemake.input.cTiter_x_ne_star_test_forecasts_path
ne_star_lbi_test_forecasts_path = snakemake.input.ne_star_lbi_test_forecasts_path

vaccines_json_path = snakemake.input.vaccines_json_path

output_figure = snakemake.output.figure

# %%
"""
validation_tip_attributes_path = "../results/builds/natural/natural_sample_1_with_90_vpm_sliding/tip_attributes_with_weighted_distances.tsv"
validation_forecasts_path = "../results/builds/natural/natural_sample_1_with_90_vpm_sliding/forecasts.tsv"

test_tip_attributes_path = "../results/builds/natural/natural_sample_1_with_90_vpm_sliding_test_tree/tip_attributes_with_weighted_distances.tsv"
test_forecasts_path = "../results/builds/natural/natural_sample_1_with_90_vpm_sliding_test_tree/forecasts.tsv"

vaccines_json_path = "../config/vaccines_h3n2.json"

output_figure = "../manuscript/figures/vaccine-comparison.pdf"
"""
# Out:
# '\nvalidation_tip_attributes_path = "../results/builds/natural/natural_sample_1_with_90_vpm_sliding/tip_attributes_with_weighted_distances.tsv"\nvalidation_forecasts_path = "../results/builds/natural/natural_sample_1_with_90_vpm_sliding/forecasts.tsv"\n\ntest_tip_attributes_path = "../results/builds/natural/natural_sample_1_with_90_vpm_sliding_test_tree/tip_attributes_with_weighted_distances.tsv"\ntest_forecasts_path = "../results/builds/natural/natural_sample_1_with_90_vpm_sliding_test_tree/forecasts.tsv"\n\nvaccines_json_path = "../config/vaccines_h3n2.json"\n\noutput_figure = "../manuscript/figures/vaccine-comparison.pdf"\n'

# %%
import json
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import pandas as pd
from pandas.plotting import register_matplotlib_converters
from scipy.stats import pearsonr, spearmanr, probplot
import seaborn as sns
import statsmodels.api as sm

# %matplotlib inline

# %%
register_matplotlib_converters()

# %%
first_validation_timepoint = "2003-10-01"

# %%
sns.set_style("ticks")

# %%
# Display figures at a reasonable default size.
mpl.rcParams['figure.figsize'] = (6, 4)

# Disable top and right spines.
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.right'] = False
    
# Display and save figures at higher resolution for presentations and manuscripts.
mpl.rcParams['savefig.dpi'] = 200
mpl.rcParams['figure.dpi'] = 200

# Display text at sizes large enough for presentations and manuscripts.
mpl.rcParams['font.weight'] = "normal"
mpl.rcParams['axes.labelweight'] = "normal"
mpl.rcParams['font.size'] = 18
mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['legend.fontsize'] = 12
mpl.rcParams['xtick.labelsize'] = 14
mpl.rcParams['ytick.labelsize'] = 14

mpl.rc('text', usetex=False)

# %% [markdown]
# ## Define functions

# %%
def calculate_weighted_distance_between_pairs(row):
    distance = (
        np.frombuffer(row["aa_sequence"].encode(), dtype="S1") !=
        np.frombuffer(row["aa_sequence_future"].encode(), dtype="S1")
    ).sum()
    return row["frequency"] * distance

def calculate_weighted_distance_by_group(group_df):
    return group_df.apply(calculate_weighted_distance_between_pairs, axis=1).sum()

# %% [markdown]
# ## Load tip attributes with sequences
#
# For each timepoint, find distinct sequences that will be used to calculate distances to the future.

# %%
validation_tips_with_sequence = pd.read_csv(
    validation_tip_attributes_path,
    sep="\t",
    parse_dates=["timepoint"],
    usecols=["strain", "timepoint", "frequency", "aa_sequence"]
)

# %%
test_tips_with_sequence = pd.read_csv(
    test_tip_attributes_path,
    sep="\t",
    parse_dates=["timepoint"],
    usecols=["strain", "timepoint", "frequency", "aa_sequence"]
)

# %%
# Retain only validation tips whose timepoints occur prior to the first
# test timepoint. This prevents us from using too many tips from overlapping
# timepoints between validation and test periods.
validation_tips_with_sequence = validation_tips_with_sequence[
    (validation_tips_with_sequence["timepoint"] < test_tips_with_sequence["timepoint"].min()) &
    (validation_tips_with_sequence["timepoint"] >= first_validation_timepoint)
].copy()

# %%
last_validation_timepoint = validation_tips_with_sequence["timepoint"].max()

# %%
last_validation_timepoint
# Out:
# Timestamp('2014-10-01 00:00:00')

# %%
distinct_validation_tips_with_sequence = validation_tips_with_sequence.groupby(
    ["timepoint", "aa_sequence"]
).first().reset_index()

# %%
distinct_test_tips_with_sequence = test_tips_with_sequence.groupby(
    ["timepoint", "aa_sequence"]
).first().reset_index()

# %%
tips_with_sequence = pd.concat([validation_tips_with_sequence, test_tips_with_sequence])

# %%
distinct_tips_with_sequence = pd.concat([distinct_validation_tips_with_sequence, distinct_test_tips_with_sequence])

# %% [markdown]
# ## Load vaccine strain data
#
# Load information about vaccine strains including their names, amino acid sequences, and the timepoint in our analysis when they were selected for the vaccine. These latter timepoints constrain the timepoints we consider in the analyses that follow.

# %%
with open(vaccines_json_path, "r") as fh:
    vaccines_json = json.load(fh)

# %%
vaccine_df = pd.DataFrame([
    {
        "strain_type": "vaccine",
        "strain": vaccine,
        "timepoint": vaccine_data["vaccine"]["timepoint"],
        "aa_sequence": vaccine_data["aa_sequence"]
    }
    for vaccine, vaccine_data in vaccines_json["nodes"].items()
])
vaccine_df["timepoint"] = pd.to_datetime(vaccine_df["timepoint"])
vaccine_df["future_timepoint"] = vaccine_df["timepoint"] + pd.DateOffset(months=12)

# %%
# Find all tips with sequences at the future timepoint for each vaccine strain.
tips_for_vaccines_df = vaccine_df.merge(
    tips_with_sequence,
    left_on=["future_timepoint"],
    right_on=["timepoint"],
    suffixes=["", "_future"]
)

# %%
vaccine_distance_to_future = tips_for_vaccines_df.groupby("timepoint").apply(
    calculate_weighted_distance_by_group
).reset_index(name="distance_to_future")

# %%
vaccine_forecasts = vaccine_df.merge(
    vaccine_distance_to_future,
    on="timepoint"
).loc[:, ["strain_type", "strain", "timepoint", "future_timepoint", "distance_to_future"]]

# %%
vaccine_forecasts
# Out:
#    strain_type                           strain  timepoint future_timepoint  \
# 0      vaccine                A/Fujian/411/2002 2003-10-01       2004-10-01
# 1      vaccine              A/Wellington/1/2004 2004-10-01       2005-10-01
# 2      vaccine              A/California/7/2004 2005-04-01       2006-04-01
# 3      vaccine              A/Wisconsin/67/2005 2006-04-01       2007-04-01
# 4      vaccine               A/Brisbane/10/2007 2007-10-01       2008-10-01
# 5      vaccine                  A/Perth/16/2009 2009-10-01       2010-10-01
# 6      vaccine              A/Victoria/361/2011 2012-04-01       2013-04-01
# 7      vaccine                  A/Texas/50/2012 2013-10-01       2014-10-01
# 8      vaccine       A/Switzerland/9715293/2013 2014-10-01       2015-10-01
# 9      vaccine             A/HongKong/4801/2014 2015-10-01       2016-10-01
# 10     vaccine  A/Singapore/Infimh-16-0019/2016 2017-10-01       2018-10-01
# ...

# %% [markdown]
# ## Load forecasts from models

# %% [markdown]
# ### Load forecasts from mutational load and LBI model

# %%
ne_star_lbi_validation_forecasts = pd.read_csv(
    ne_star_lbi_validation_forecasts_path,
    sep="\t",
    parse_dates=["timepoint", "future_timepoint"]
)

# %%
ne_star_lbi_validation_forecasts = ne_star_lbi_validation_forecasts.query(
    "timepoint >= '%s'" % first_validation_timepoint
).dropna().copy()

# %%
ne_star_lbi_test_forecasts = pd.read_csv(
    ne_star_lbi_test_forecasts_path,
    sep="\t",
    parse_dates=["timepoint", "future_timepoint"]
).dropna()

# %%
ne_star_lbi_forecasts = pd.concat([
    ne_star_lbi_validation_forecasts,
    ne_star_lbi_test_forecasts
])
ne_star_lbi_forecasts = ne_star_lbi_forecasts[
    ne_star_lbi_forecasts["timepoint"].isin(vaccine_forecasts["timepoint"])
].copy()

# %% [markdown]
# ### Load forecasts from HI antigenic novelty and mutational load model

# %%
cTiter_x_ne_star_validation_forecasts = pd.read_csv(
    cTiter_x_ne_star_validation_forecasts_path,
    sep="\t",
    parse_dates=["timepoint", "future_timepoint"]
)

# %%
cTiter_x_ne_star_validation_forecasts = cTiter_x_ne_star_validation_forecasts.query(
    "timepoint >= '%s'" % first_validation_timepoint
).dropna().copy()

# %%
cTiter_x_ne_star_test_forecasts = pd.read_csv(
    cTiter_x_ne_star_test_forecasts_path,
    sep="\t",
    parse_dates=["timepoint", "future_timepoint"]
).dropna()

# %%
cTiter_x_ne_star_forecasts = pd.concat([
    cTiter_x_ne_star_validation_forecasts,
    cTiter_x_ne_star_test_forecasts
])
cTiter_x_ne_star_forecasts = cTiter_x_ne_star_forecasts[
    cTiter_x_ne_star_forecasts["timepoint"].isin(vaccine_forecasts["timepoint"])
].copy()

# %% [markdown]
# ## Identify observed closest strains to the future
#
# Use strains from forecast models with annotated weighted distances to the future to find observed closest strains to the future per timepoint with a vaccine.

# %%
combined_forecasts = pd.concat([
    ne_star_lbi_forecasts,
    cTiter_x_ne_star_forecasts
])

# %%
observed_closest_strains = combined_forecasts.sort_values(["timepoint", "weighted_distance_to_future"]).groupby(
    "timepoint"
).first().reset_index().loc[:, ["timepoint", "future_timepoint", "strain", "weighted_distance_to_future"]]
observed_closest_strains["strain_type"] = "observed closest"
observed_closest_strains = observed_closest_strains.rename(
    columns={"weighted_distance_to_future": "distance_to_future"}
)

# %%
observed_closest_strains
# Out:
#     timepoint future_timepoint                         strain  \
# 0  2003-10-01       2004-10-01              A/Jiangxi/20/2003
# 1  2004-10-01       2005-10-01             A/Jeonnam/336/2004
# 2  2005-04-01       2006-04-01          A/Malaysia/31944/2005
# 3  2006-04-01       2007-04-01           A/England/61007/2006
# 4  2007-10-01       2008-10-01             A/Hanoi/BM238/2007
# 5  2009-10-01       2010-10-01    A/BadenWurttemberg/209/2009
# 6  2012-04-01       2013-04-01         A/Anhui-Jinan/173/2012
# 7  2013-10-01       2014-10-01      A/AmericanSamoa/4796/2013
# 8  2014-10-01       2015-10-01           A/Asturias/1949/2014
# 9  2015-10-01       2016-10-01              A/Brazil/187/2015
# 10 2017-10-01       2018-10-01            A/Ayutthaya/73/2017
# 11 2018-10-01       2019-10-01  A/Shanghai-Huangpu/11325/2018
#
#     distance_to_future       strain_type
# 0             4.077711  observed closest
# 1             3.317366  observed closest
# ...

# %% [markdown]
# ## Identify estimated closest strains to the future by model
#
# Use strains from forecast models with annotated weighted distances to the future to find estimated closest strains to the future per timepoint with a vaccine.

# %% [markdown]
# ### Identify estimated closest strains to the future by mutational load and LBI

# %%
estimated_closest_strains_by_ne_star_lbi = ne_star_lbi_forecasts.sort_values(
    ["timepoint", "y"]
).groupby(
    "timepoint"
).first().reset_index().loc[:, ["timepoint", "future_timepoint", "strain", "weighted_distance_to_future"]]
estimated_closest_strains_by_ne_star_lbi["strain_type"] = "estimated closest by ne_star-lbi"
estimated_closest_strains_by_ne_star_lbi = estimated_closest_strains_by_ne_star_lbi.rename(
    columns={"weighted_distance_to_future": "distance_to_future"}
)

# %%
estimated_closest_strains_by_ne_star_lbi
# Out:
#     timepoint future_timepoint                     strain  distance_to_future  \
# 0  2003-10-01       2004-10-01  A/Australia/NHRC0001/2003            8.435527
# 1  2004-10-01       2005-10-01            A/Dakar/18/2004            4.378632
# 2  2005-04-01       2006-04-01      A/Austria/212187/2005            4.601412
# 3  2006-04-01       2007-04-01  A/Canada/CN-RV657-06/2006            5.363311
# 4  2007-10-01       2008-10-01            A/Aichi/67/2007            3.784125
# 5  2009-10-01       2010-10-01           A/Morobe/10/2009            6.946014
# 6  2012-04-01       2013-04-01           A/Aichi/233/2011            3.723947
# 7  2013-10-01       2014-10-01          A/Chiba-C/44/2013            6.539906
# 8  2014-10-01       2015-10-01     A/Bangladesh/2008/2014            3.882022
# 9  2015-10-01       2016-10-01           A/Arizona/7/2015            7.326317
# 10 2017-10-01       2018-10-01            A/Akita/21/2017            7.467113
# ...

# %% [markdown]
# ### Identify estimated closest strains to the future by HI antigenic novelty and mutational load

# %%
estimated_closest_strains_by_cTiter_x_ne_star = cTiter_x_ne_star_forecasts.sort_values(
    ["timepoint", "y"]
).groupby(
    "timepoint"
).first().reset_index().loc[:, ["timepoint", "future_timepoint", "strain", "weighted_distance_to_future"]]
estimated_closest_strains_by_cTiter_x_ne_star["strain_type"] = "estimated closest by cTiter_x-ne_star"
estimated_closest_strains_by_cTiter_x_ne_star = estimated_closest_strains_by_cTiter_x_ne_star.rename(
    columns={"weighted_distance_to_future": "distance_to_future"}
)

# %%
estimated_closest_strains_by_cTiter_x_ne_star
# Out:
#     timepoint future_timepoint                  strain  distance_to_future  \
# 0  2003-10-01       2004-10-01      A/Hanoi/BM766/2003            6.497199
# 1  2004-10-01       2005-10-01         A/Dakar/18/2004            4.378632
# 2  2005-04-01       2006-04-01   A/Austria/212187/2005            4.601412
# 3  2006-04-01       2007-04-01   A/Anhui-Baohe/10/2005            5.368142
# 4  2007-10-01       2008-10-01         A/Aichi/67/2007            3.784125
# 5  2009-10-01       2010-10-01        A/Aichi/689/2009            7.932002
# 6  2012-04-01       2013-04-01        A/Alaska/17/2011            7.016824
# 7  2013-10-01       2014-10-01        A/Alabama/7/2013            6.890131
# 8  2014-10-01       2015-10-01  A/Bangladesh/2008/2014            3.882022
# 9  2015-10-01       2016-10-01       A/Alaska/115/2015            6.085611
# 10 2017-10-01       2018-10-01    A/Philippines/7/2017            7.812084
# ...

# %% [markdown]
# ## Plot distance to the future by timepoint and strain type
#
# Compare distances to the future for selected vaccine strains and the observed and estimated closest strains to the future.

# %%
colors_by_strain_type = {
    "vaccine strain": "#2ca02c",
    "observed best": "#1f77b4",
    "estimated best by ne_star-lbi": "#ff7f0e",
    "estimated best by cTiter_x-ne_star": "#9467bd",
}

# %% [markdown]
# Split data frames into validation and test periods.

# %%
observed_closest_strains_for_validation = observed_closest_strains[
    observed_closest_strains["timepoint"] <= last_validation_timepoint
]
estimated_closest_strains_by_cTiter_x_ne_star_for_validation = estimated_closest_strains_by_cTiter_x_ne_star[
    estimated_closest_strains_by_cTiter_x_ne_star["timepoint"] <= last_validation_timepoint
]
estimated_closest_strains_by_ne_star_lbi_for_validation = estimated_closest_strains_by_ne_star_lbi[
    estimated_closest_strains_by_ne_star_lbi["timepoint"] <= last_validation_timepoint
]
vaccine_forecasts_for_validation = vaccine_forecasts[
    vaccine_forecasts["timepoint"] <= last_validation_timepoint
]

# %%
observed_closest_strains_for_test = observed_closest_strains[
    observed_closest_strains["timepoint"] > last_validation_timepoint
]
estimated_closest_strains_by_cTiter_x_ne_star_for_test = estimated_closest_strains_by_cTiter_x_ne_star[
    estimated_closest_strains_by_cTiter_x_ne_star["timepoint"] > last_validation_timepoint
]
estimated_closest_strains_by_ne_star_lbi_for_test = estimated_closest_strains_by_ne_star_lbi[
    estimated_closest_strains_by_ne_star_lbi["timepoint"] > last_validation_timepoint
]
vaccine_forecasts_for_test = vaccine_forecasts[
    vaccine_forecasts["timepoint"] > last_validation_timepoint
]

# %%
max_distance_to_future = max(
    observed_closest_strains["distance_to_future"].max(),
    estimated_closest_strains_by_ne_star_lbi["distance_to_future"].max(),
    estimated_closest_strains_by_cTiter_x_ne_star["distance_to_future"].max(),
    vaccine_forecasts["distance_to_future"].max()
)

# %%
max_distance_to_future
# Out:
# 17.078473000000006

# %%
distance_ticks = np.arange(int(np.ceil(max_distance_to_future)) + 2, step=2)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 3.5))
#ax = axes[0]

strain_alpha=0.5

# Plot validation results.
ax.plot(
    observed_closest_strains_for_validation["timepoint"],
    observed_closest_strains_for_validation["distance_to_future"],
    "o-",
    color=colors_by_strain_type["observed best"],
    alpha=strain_alpha,
    label="observed best"
)

ax.plot(
    estimated_closest_strains_by_cTiter_x_ne_star_for_validation["timepoint"],
    estimated_closest_strains_by_cTiter_x_ne_star_for_validation["distance_to_future"],
    "o-",
    color=colors_by_strain_type["estimated best by cTiter_x-ne_star"],
    alpha=strain_alpha,
    label="estimated best by HI + mutational load"
)

ax.plot(
    estimated_closest_strains_by_ne_star_lbi_for_validation["timepoint"],
    estimated_closest_strains_by_ne_star_lbi_for_validation["distance_to_future"],
    "o-",
    color=colors_by_strain_type["estimated best by ne_star-lbi"],
    alpha=strain_alpha,
    label="estimated best by mutational load + LBI"
)

ax.plot(
    vaccine_forecasts_for_validation["timepoint"],
    vaccine_forecasts_for_validation["distance_to_future"],
    "o-",
    color=colors_by_strain_type["vaccine strain"],
    alpha=strain_alpha,
    label="vaccine strain"
)

# Plot test results.
ax.plot(
    observed_closest_strains_for_test["timepoint"],
    observed_closest_strains_for_test["distance_to_future"],
    "o-",
    color=colors_by_strain_type["observed best"],
    alpha=strain_alpha
)

ax.plot(
    estimated_closest_strains_by_cTiter_x_ne_star_for_test["timepoint"],
    estimated_closest_strains_by_cTiter_x_ne_star_for_test["distance_to_future"],
    "o-",
    color=colors_by_strain_type["estimated best by cTiter_x-ne_star"],
    alpha=strain_alpha
)

ax.plot(
    estimated_closest_strains_by_ne_star_lbi_for_test["timepoint"],
    estimated_closest_strains_by_ne_star_lbi_for_test["distance_to_future"],
    "o-",
    color=colors_by_strain_type["estimated best by ne_star-lbi"],
    alpha=strain_alpha
)

ax.plot(
    vaccine_forecasts_for_test["timepoint"],
    vaccine_forecasts_for_test["distance_to_future"],
    "o-",
    color=colors_by_strain_type["vaccine strain"],
    alpha=strain_alpha
)

for index, record in vaccine_forecasts.iterrows():
    ax.text(
        record["timepoint"],
        record["distance_to_future"],
        record["strain"],
        fontsize=8
    )

ax.axvline(
    last_validation_timepoint,
    zorder=-10,
    alpha=0.2,
    color="#000000",
    linestyle="-",
    label="Last validation timepoint"
)

ax.legend(
    loc=(0.01, 0.65),
    frameon=False,
    fontsize=10
)

ax.set_yticks(distance_ticks)

ax.set_xlabel("Date")
ax.set_ylabel("Weighted distance\nto the future (AAs)")
ax.set_ylim(bottom=0)

plt.tight_layout()
plt.savefig(output_figure, bbox_inches="tight")

# %%
merged_model_and_vaccine_ne_star_lbi = vaccine_forecasts.merge(
    estimated_closest_strains_by_ne_star_lbi,
    on=["timepoint"],
    suffixes=["_vaccine", "_model"]
)

# %%
merged_model_and_vaccine_ne_star_lbi["vaccine_minus_model"] = (
    merged_model_and_vaccine_ne_star_lbi["distance_to_future_vaccine"] - 
    merged_model_and_vaccine_ne_star_lbi["distance_to_future_model"]
)

# %%
merged_model_and_vaccine_ne_star_lbi["vaccine_minus_model"]
# Out:
# 0     1.007000
# 1     1.699958
# 2     2.894438
# 3     4.941565
# 4     1.999962
# 5     1.004941
# 6     2.541889
# 7     2.110323
# 8     6.942614
# 9    -1.240706
# 10    1.146931
# 11   -1.913147
# Name: vaccine_minus_model, dtype: float64

# %%
(merged_model_and_vaccine_ne_star_lbi["vaccine_minus_model"] < 0).sum()
# Out:
# 2

# %%
merged_model_and_vaccine_ne_star_lbi[
    merged_model_and_vaccine_ne_star_lbi["vaccine_minus_model"] < 0
]["vaccine_minus_model"].mean()
# Out:
# -1.5769265000000021

# %%
merged_model_and_vaccine_ne_star_lbi[
    merged_model_and_vaccine_ne_star_lbi["vaccine_minus_model"] >= 0
]["vaccine_minus_model"].mean()
# Out:
# 2.6289620999999994

# %%
merged_model_and_vaccine_cTiter_x_ne_star = vaccine_forecasts.merge(
    estimated_closest_strains_by_cTiter_x_ne_star,
    on=["timepoint"],
    suffixes=["_vaccine", "_model"]
)

# %%
merged_model_and_vaccine_cTiter_x_ne_star["vaccine_minus_model"] = (
    merged_model_and_vaccine_cTiter_x_ne_star["distance_to_future_vaccine"] -
    merged_model_and_vaccine_cTiter_x_ne_star["distance_to_future_model"]
)

# %%
merged_model_and_vaccine_cTiter_x_ne_star["vaccine_minus_model"]
# Out:
# 0     2.945328e+00
# 1     1.699958e+00
# 2     2.894438e+00
# 3     4.936734e+00
# 4     1.999962e+00
# 5     1.895300e-02
# 6    -7.509880e-01
# 7     1.760098e+00
# 8     6.942614e+00
# 9     8.881784e-16
# 10    8.019600e-01
# 11    4.746683e+00
# Name: vaccine_minus_model, dtype: float64

# %%
(merged_model_and_vaccine_cTiter_x_ne_star["vaccine_minus_model"] < 0).sum()
# Out:
# 1

# %%
merged_model_and_vaccine_cTiter_x_ne_star[
    merged_model_and_vaccine_cTiter_x_ne_star["vaccine_minus_model"] < 0
]["vaccine_minus_model"]
# Out:
# 6   -0.750988
# Name: vaccine_minus_model, dtype: float64

# %%
merged_model_and_vaccine_cTiter_x_ne_star[
    merged_model_and_vaccine_cTiter_x_ne_star["vaccine_minus_model"] >= 0
]["vaccine_minus_model"].mean()
# Out:
# 2.6133389090909103
